# %%
import pandas as pd

# %%
#leer el archivo Reporte de ventas por articulos MOD 2.xlsx como df
df = pd.read_excel('Reporte de ventas por articulos MOD 2.xlsx')

# %%
df
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 0     R124132  VIDRIO GLASS SAMSUNG  A02S / A03 / A03 CORE / ...      90.0
# 1      PI3017                       Pilas Boton 3 V Philco 2032       70.0
# 2       D1014  CABLE USB ONLY MOD48 / V8 / 3,1A BLANCO Y NEGR...      55.0
# 3          C6  Pin Carga Sam J7 pro / J7 prime / J5 prime / J...      54.0
# 4       SE966            SERVICIO TECNICO REVISION Y PRESUPUESTO      54.0
# ...       ...                                                ...       ...
# 1550  RC76393  BATERIA SAM A14 / A52 / S20 FE / A52S 100% Ori...      -1.0
# 1551   PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
# 1552      NaN                                                NaN       NaN
# 1553      NaN                                                NaN       NaN
# 1554      NaN                                                NaN    6294.0
#
#       Costo total      Ganancia  Ganancia prom. %   Venta total  \
# ...

# %%
#pasar a str la columna nombre del producto y la columna categoria
df['Nombre del Producto'] = df['Nombre del Producto'].astype(str)
df['Categoria'] = df['Categoria'].astype(str)

# %%
#ver valores ocn la cadena case disco en la columan nombre del producto
df[df['Nombre del Producto'].str.contains('case disco', case=False)]
# Out:
#     Código                       Nombre del Producto  Cantidad  Costo total  \
# 376  D8211  CASE DISCO 3.0 Seisa Tranparente Dn-k209       4.0         16.2
#
#          Ganancia  Ganancia prom. %  Venta total  \
# 376  31980.399658          197431.0      32000.0
#
#                                     Categoria
# 376  CASE DISCO 3.0 Seisa Tranparente Dn-k209

# %%
#agregar en la columna categoria la cadena 'Accesorio Disco' si la columna nombre del producto contiene la cadena 'case disco'
df.loc[df['Nombre del Producto'].str.contains('case disco', case=False), 'Categoria'] = 'Accesorio Disco'

# %%
#ver valores con la cadena analogico
df[df['Nombre del Producto'].str.contains('analogico', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 640    CO126  Analogico Nintendo Switch Joy-Con Joystick Rep...       2.0
# 1161  CO1162  Grip Para Analogico Nintendo Switch Joy Con Y ...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 640          9.24  59988.817169          649251.0      60000.0
# 1161         3.77   7995.441781          212102.0       8000.0
#
#                                               Categoria
# 640   Analogico Nintendo Switch Joy-Con Joystick Rep...
# 1161  Grip Para Analogico Nintendo Switch Joy Con Y ...

# %%
#agregar en la columna categoria la cadena 'Repuesto Joystick' si la columna nombre del producto contiene la cadena 'analogico'
df.loc[df['Nombre del Producto'].str.contains('analogico', case=False), 'Categoria'] = 'Repuesto Joystick'

# %%
#ver valores que tengna estricamente la cadena pad y su columna categoria tiene mas de dos palabra
df[(df['Nombre del Producto'].str.contains('pad', case=False)) & (df['Categoria'].str.contains(r'\b\w+\b \b\w+\b \b\w+\b', regex=True))]
#Cambiar la categoria de esas filas encontradas a Mousepad
df.loc[(df['Nombre del Producto'].str.contains('pad', case=False)) & (df['Categoria'].str.contains(r'\b\w+\b \b\w+\b \b\w+\b', regex=True)), 'Categoria'] = 'Mousepad'

# %%
#cambiar la categoria de las filas que contengan la cadena 'analogo' a 'Repuesto Joystick'
df.loc[df['Nombre del Producto'].str.contains('analogo', case=False), 'Categoria'] = 'Repuesto Joystick'

# %%
#ver valores con la cadena analogico
df[df['Nombre del Producto'].str.contains('analogico|analogo', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 354   CO6263         ANALOGO JOYSTICK REPUESTO PS4 PS5 XBOX ONE       4.0
# 640    CO126  Analogico Nintendo Switch Joy-Con Joystick Rep...       2.0
# 1161  CO1162  Grip Para Analogico Nintendo Switch Joy Con Y ...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 354          9.28  144988.756393      1.580990e+11     146725.5
# 640          9.24   59988.817169      6.492510e+05      60000.0
# 1161         3.77    7995.441781      2.121020e+05       8000.0
#
#               Categoria
# 354   Repuesto Joystick
# 640   Repuesto Joystick
# 1161  Repuesto Joystick

# %%
#ver valores con la cadena joystick
df[df['Nombre del Producto'].str.contains('joystick', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 121       C2512        JOYSTICK XBOX 360 / PC CON CABLE 52A NJX301      10.0
# 165      CO6258  JOYSTICK INALAMBRICO SEISA SJ-913 COLORES PC /...       8.0
# 166       C6239  Joystick Bluetooth Con Soporte para Celular Se...       8.0
# 354      CO6263         ANALOGO JOYSTICK REPUESTO PS4 PS5 XBOX ONE       4.0
# 396   JOY-61020    JOYSTICK PLAYSTATION PS4 DUALSHOCK COLORES WB-6       4.0
# 514   JOY-61012  JOYSTICK PLAYSTATION PS4 TIME CAMUFALDOS JOY-6...       3.0
# 515     JO11389  JOYSTICK XBOX 360/PC/ANDROID INALAMBRICO + DON...       3.0
# 516    JO113101  Joystick Redragon Inalambrico Harrow PRO G808-...       3.0
# 517       R6116    Joystick Redragon Saturn G807 Windows/Ps3 negro       3.0
# 640       CO126  Analogico Nintendo Switch Joy-Con Joystick Rep...       2.0
# 676       CO112              CABLE CARGA Y JUEGA JOYSTICK XBOX 360       2.0
# ...

# %%
#ver valores con la cadena joystick y su columna categoria sea diferente de 'Repuesto Joystick', 'joystick', 'consola'
df[(df['Nombre del Producto'].str.contains('joystick', case=False)) & (~df['Categoria'].str.contains('Repuesto Joystick|Joystick|Consola'))]
# Out:
#          Código                              Nombre del Producto  Cantidad  \
# 723       C6253     FILM MEMBRANA CONDUCTOR JOYSTICK PS4 JDM-040       2.0
# 744        2741  Joystick PS3 Bluetooth Sony Dualshock 3 SIMIL O       2.0
# 1441  CO1129546    SOPORTE DE CARGADOR PARA PS5 JOYSTICK SND-463       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 723          5.48  14993.372294          273623.0     15000.00
# 744         20.10  32475.689498          181492.0     36500.00
# 1441         9.27  16592.533300          179013.0     16603.75
#
#                                           Categoria
# 723    FILM MEMBRANA CONDUCTOR JOYSTICK PS4 JDM-040
# 744                                      Badeja SIM
# 1441  SOPORTE DE CARGADOR PARA PS5 JOYSTICK SND-463

# %%
#en esos valores cambiar su categoria a 'Repuesto Joystick' solo si tienen la cadena membrana y soporte
df.loc[(df['Nombre del Producto'].str.contains('joystick', case=False)) & (~df['Categoria'].str.contains('Repuesto Joystick|Joystick|Consola')) & (df['Nombre del Producto'].str.contains('membrana|soporte', case=False)), 'Categoria'] = 'Repuesto Joystick'

# %%
#ver valores con la cadena joystick y su cattegoria se igual a Badeja SIM
df[(df['Nombre del Producto'].str.contains('joystick', case=False)) & (df['Categoria'] == 'Badeja SIM')]
#cambiar su categoria a 'Joystick'
df.loc[(df['Nombre del Producto'].str.contains('joystick', case=False)) & (df['Categoria'] == 'Badeja SIM'), 'Categoria'] = 'Joystick'

# %%
#ver valores con la cadene enchufe
df[df['Nombre del Producto'].str.contains('enchufe', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 289    A7030  Adaptador Enchufes Universal Viajero Reforzado...       5.0
# 909   AD7046  ADAPTADOR INTERNATIONAL DIVERSOS ENCHUFES SS17...       1.0
# 1118  AS1522      ENCHUFE INTELIGENTE WIFI SMART PLUG SA-014 GB       1.0
# 1258  LU9847  Mini Bola Led Rgb Led Party Light Enchufe A 22...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 289          1.89  11497.720890          608366.0      11500.0
# 909          2.20   5997.341039          272627.0       6000.0
# 1118         7.53  18990.883562          252224.0      19000.0
# 1258         6.65  11991.954743          180351.0      12000.0
#
#                                           Categoria
# 289                                       Adaptador
# 909                                       Adaptador
# 1118  ENCHUFE INTELIGENTE WIFI SMART PLUG SA-014 GB
# 1258                                          Luces

# %%
#Cambiar la categoria de los productos a 'Asistente Virtual' para los productos que tengan en su nombre la cadaena enchufe inteligente
df.loc[df['Nombre del Producto'].str.contains('enchufe inteligente', case=False), 'Categoria'] = 'Asistente Virtual'

# %%
#ver valores con la cadena tv
df[df['Nombre del Producto'].str.contains('tv', case=False)]
# Out:
#                Código                                Nombre del Producto  \
# 80            TV10915  Chromecast Google Tv HD 8gb Blanco Con Control...
# 111          CA712086  TRANSFORMADOR FUENTE TIRA DE LED CCTV CAMARAS ...
# 225             S9310          SOPORTE TV FIJO 26 A 55 DINAX DX-STVF2655
# 277           SO11018  SOPORTE TV MOVIL CON BRAZO 26 A 55 SEISA GJ-CP303
# 339           SO11019           SOPORTE TV FIJO 14 A 42 DELHIP DL-FJ1442
# 440   TVS-ARM2-30-60I  SOPORTE TV DOBLE BRAZO MOVIL GLOBAL 30 A 60 IN...
# 591         SO1101559  SOPORTE TV FIJO SEISA 42 A 85" HASTA 100KG/ Co...
# 678           CA74191          CABLE HDMI A VGA 1.5M MALLADO HDTV TO VGA
# 858           SO11014  SOPORTE LCD BRAZO DOBLE 26 A 55 DINAX DX-SM2655TV
# 867           TV15112                      TV BOX MXQ-4K (1GB+8GB) Peiso
# 1023         PA131144  Barra Sonido Tv o Pc Bluetooth / Sd / Radio / ...
# 1260             P635  Mini Teclado Only Smart Tv Bluetooth Retroilum...
# ...

# %%
#ver valores con la cadena tv y que su categoria sea distinta de la cadena: Herramienta, Soporte, Cable, Teclado y Parlante
df[(df['Nombre del Producto'].str.contains('tv', case=False)) & (~df['Categoria'].str.contains('Herramienta|Soporte|Cable|Teclado|Parlante'))]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 867   TV15112                      TV BOX MXQ-4K (1GB+8GB) Peiso       2.0
# 1470  TV10917                              TV BOX (2G+16G) TX100       1.0
# 1471  TV10918                               TV BOX T96D (2G+16G)       1.0
# 1529   TV7618       Xiaomi Mi Tv Stick 4k Ram 2gb 8gb Android Tv       1.0
# 1541  TV10919  CONVERTIDOR TV STICK 2GB 16GB ANDROID 10 SYSTE...       0.0
# 1548  CO11264  XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + AND...       0.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 867         38.92  107952.898402          277392.0     108000.0
# 1470        47.31   84942.754900          179566.0      85000.0
# 1471        45.17   87445.344300          193613.0      87500.0
# 1529        57.13   99430.867009          174064.0      99500.0
# 1541         0.00       0.000000               NaN          0.0
# ...

# %%
#A esos valores cambiar su categoria a 'TV Box'
df.loc[(df['Nombre del Producto'].str.contains('tv', case=False)) & (~df['Categoria'].str.contains('Herramienta|Soporte|Cable|Teclado|Parlante')), 'Categoria'] = 'TV Box'

# %%
#ver valores con la cadena sillon
df[df['Nombre del Producto'].str.contains('sillon', case=False)]
# Out:
#       Código             Nombre del Producto  Cantidad  Costo total  \
# 1427  SA1356  SILLON MASAJEADOR SUONO 174881       1.0        14.99
#
#           Ganancia  Ganancia prom. %  Venta total  \
# 1427  19983.439506          133322.0      20000.0
#
#                            Categoria
# 1427  SILLON MASAJEADOR SUONO 174881

# %%
#cambiar categoria a 'Salud' para los productos que tengan en su nombre la cadena sillon
df.loc[df['Nombre del Producto'].str.contains('sillon', case=False), 'Categoria'] = 'Salud'

# %%
#ver valores con la cadena tostadora
df[df['Nombre del Producto'].str.contains('tostadora', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 1467  EL6715  TOSTADORA ELECTRICA ATMA DISNEY TOAT39DN - Mic...       1.0
#
#       Costo total    Ganancia  Ganancia prom. %  Venta total  \
# 1467        27.23  45967.0517          168831.0      46000.0
#
#                                               Categoria
# 1467  TOSTADORA ELECTRICA ATMA DISNEY TOAT39DN - Mic...

# %%
#cambiar categoria a 'Electrodomesticos' para los productos que tengan en su nombre la cadena tostadora
df.loc[df['Nombre del Producto'].str.contains('tostadora', case=False), 'Categoria'] = 'Electrodomesticos'

# %%
#ver valores con la cadena wifi
df[df['Nombre del Producto'].str.contains('wifi', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 270     CO953       PLACA USB/WIFI 150M CON ANTENA 5DBI DNW150U2       6.0
# 434    CO8138  Receptor USB NANO Wireless WIFI AC600 Dual ban...       4.0
# 467     C8114  Antena Externa Adaptador Usb Wifi Placa Red La...       3.0
# 533     C8118  Mini Adaptador USB Wifi tp-link TL-WN823N 300M...       3.0
# 569     CO952  PLACA USB/WIFI 150M CON ANTENA DN-W150U3 or 13...       3.0
# 698   CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 699   CA11438  Camara De Seguridad IPC-ZAS05 DOBLE LENTE 360 ...       2.0
# 701    CA7431  Camara wifi Ezviz interior inteligente - C6N 1...       2.0
# 848     CO957  RECEPTOR WIFI DINAX DOBLE BANDA 1300MBPS / DXR...       2.0
# 851     CO946  ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...       2.0
# 951   NG-Uw06  Adaptador Inalambrico Wifi Usb Red Noga NG-Uw0...       1.0
# ...

# %%
#cambiar categoria a 'Conectividad' para los productos que tengan en su nombre la cadena wifi y qeu su categoria sea distinta de : Herramienta, Asistente Virtual, Luces, Adaptador y Router
df.loc[(df['Nombre del Producto'].str.contains('wifi', case=False)) & (~df['Categoria'].str.contains('Herramienta|Asistente Virtual|Luces|Adaptador|Router')), 'Categoria'] = 'Conectividad'

# %%
#cambiar categoria a 'Conectividad' para los productos que tengan en su nombre la cadena adaptador inalambrico wifi
df.loc[df['Nombre del Producto'].str.contains('adaptador inalambrico wifi', case=False), 'Categoria'] = 'Conectividad'

# %%
#ver valores con la cadena extensor
df[df['Nombre del Producto'].str.contains('extensor', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 203    CA74155  Cable Extensor Usb 2.0 Macho A Macho Con Filtr...       7.0
# 387      CO949   EXTENSOR / REPETIDOR KANJI KJN-RP4200B 4 ANTENAS       4.0
# 714      CO950             EXTENSOR / REPETIDOR KANJI KJN-RP4200A       2.0
# 715   EXTRE200  EXTENSOR DE RANGO Tp-Link Re200 Dual Band 2.4G...       2.0
# 1126    AD2110  EXTENSOR DE HDMI POR UTP RED ETHERNET 30M GM57...       1.0
# 1127   CO95761  EXTENSOR DE RANGO De Wifi 300mbps 2.4ghz REP-R...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %   Venta total  \
# 203         23.92   48371.073702          202241.0   48400.00320
# 387         52.72  101941.717753          193375.0  101999.99515
# 714         20.34   33977.521575          167058.0   34000.00000
# 715         52.20   90742.319000          173846.0   90800.00000
# 1126         4.18    7494.940377          179326.0    7500.00000
# ...

# %%
#cambiar su cateogira a 'Conectividad'
df.loc[df['Categoria'] == 'Extensor Wifi', 'Categoria'] = 'Conectividad'

# %%
#ver valores con la cadena apolo
df[df['Nombre del Producto'].str.contains('apollo', case=False)]
# Out:
#      Código Nombre del Producto  Cantidad  Costo total      Ganancia  \
# 912  H89161       APOLLO QIANLI       1.0        98.81  219890.81495
#
#      Ganancia prom. %  Venta total      Categoria
# 912          222550.0     220000.0  APOLLO QIANLI

# %%
#cambiar su categoria a 'Herramienta' para los productos que tengan en su nombre la cadena apollo
df.loc[df['Nombre del Producto'].str.contains('apollo', case=False), 'Categoria'] = 'Herramienta'

# %%
#ver valores con la cadena cubre
df[df['Nombre del Producto'].str.contains('cubre', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 202  CO11260  CUBRE DEDOS X2 PUBG COD MOBILE FREEFIRE ANTI-S...       7.0
#
#      Costo total    Ganancia  Ganancia prom. %  Venta total  \
# 202         4.33  12594.7607          290893.0      12600.0
#
#                                              Categoria
# 202  CUBRE DEDOS X2 PUBG COD MOBILE FREEFIRE ANTI-S...

# %%
#cambiar la cattegoria de ese producto a Accesorio Gamer
df.loc[df['Nombre del Producto'].str.contains('cubre', case=False), 'Categoria'] = 'Accesorio Gamer'

# %%
#ver valores con la cadena zapatilla
df[df['Nombre del Producto'].str.contains('zapatilla', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 1530  EL877  Zapatilla Binorma 5 Bocas cable 1.5 Mtrs c/lla...       1.0
#
#       Costo total     Ganancia  Ganancia prom. %  Venta total  \
# 1530         4.08  6995.061929          171469.0       7000.0
#
#                                               Categoria
# 1530  Zapatilla Binorma 5 Bocas cable 1.5 Mtrs c/lla...

# %%
#cambiar la categoria de esos productos a 'Electricidad'
df.loc[df['Nombre del Producto'].str.contains('zapatilla', case=False), 'Categoria'] = 'Electricidad'

# %%
#cambiar la categoria a Herramienta para los productos que tengan las siguientes cadenas: mascara uv
df.loc[df['Nombre del Producto'].str.contains('mascara uv', case=False), 'Categoria'] = 'Herramienta'

# %%
#Cambiar la categoria de los produtos con la cadena balanza
df.loc[df['Nombre del Producto'].str.contains('balanza', case=False), 'Categoria'] = 'Accesorio'

# %%
#ver valores con la cadena balanza
df[df['Nombre del Producto'].str.contains('balanza', case=False)]
# Out:
#     Código                                Nombre del Producto  Cantidad  \
# 645  A1003  BALANZA MINI DIGITAL DE PRECISION 500G / 0.1G ...       2.0
#
#      Costo total      Ganancia  Ganancia prom. %  Venta total  Categoria
# 645         7.54  15590.883562          206797.0      15600.0  Accesorio

# %%
#cambiar categoria a 'Adaptador' de los productos que tengan en su cadena placa de sonido
df.loc[df['Nombre del Producto'].str.contains('placa de sonido', case=False), 'Categoria'] = 'Adaptador'

# %%
#cambiar categoria a 'Conectividad' de los productos que tengan en su caden placa de red
df.loc[df['Nombre del Producto'].str.contains('placa de red', case=False), 'Categoria'] = 'Conectividad'

# %%
#ver valores con la categoria disco
df[df['Categoria'].str.contains('Disco')]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 164   SSD480KIN   Disco Solido SSD 480GB KINGSTON A400 SATAIII 2.5       8.0
# 376       D8211           CASE DISCO 3.0 Seisa Tranparente Dn-k209       4.0
# 383   SSD240KIN   Disco Solido SSD 240GB KINGSTON A400 SATAIII 2.5       4.0
# 494      DI1244      Disco Solido SSD 128GB PATRIOT P220 2.5" SATA       3.0
# 495    DI829215             Disco Solido SSD 1TB PATRIOT P210 Sata       3.0
# 496      DI1239           Disco Solido SSD 480GB  ADATA SU630 Sata       3.0
# 673      AD2145  CABLE ADAPTADOR DISCO SATA EXTERNO A USB 3,0 /...       2.0
# 694      09-038  Cable USB a USB 3.0 Disco Externo Cable 1 Metr...       2.0
# 707      DI1169  Disco Externo Toshiba Canvio 2tb Black Usb 3.0...       2.0
# 708      DI1238            Disco Solido SSD 240GB ADATA SU630 Sata       2.0
# 709      DI1234             Disco Solido SSD 512GB VERBATIM SATA 3       2.0
# ...

# %%
#ver valores que tengan al mens las siguientes dos cadenas disco y cable
df[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('cable', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 135   DI11610  CARCASA EXTERNA PARA DISCO RIGIDO 2.5 CON CABL...       9.0
# 673    AD2145  CABLE ADAPTADOR DISCO SATA EXTERNO A USB 3,0 /...       2.0
# 694    09-038  Cable USB a USB 3.0 Disco Externo Cable 1 Metr...       2.0
# 1078  TR-1005  Cable Sata Power Molex Discos Rigidos 4 Pin No...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %   Venta total  \
# 135         66.60  115726.406550          173774.0  115799.99955
# 673         13.48   24385.104600          180909.0   24400.00000
# 694          7.52   14890.905200          198038.0   14900.00440
# 1078         0.31    2499.620148          806352.0    2500.00000
#
#                Categoria
# 135   Accesorio notebook
# 673                Disco
# 694                Disco
# 1078               Disco

# %%
#ver valores con la cadena carcasa
df[df['Nombre del Producto'].str.contains('carcasa', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 135  DI11610  CARCASA EXTERNA PARA DISCO RIGIDO 2.5 CON CABL...       9.0
#
#      Costo total      Ganancia  Ganancia prom. %   Venta total  \
# 135         66.6  115726.40655          173774.0  115799.99955
#
#               Categoria
# 135  Accesorio notebook

# %%
#cambiar la categoria de ese producto a 'Disco externo'
df.loc[df['Nombre del Producto'].str.contains('carcasa', case=False), 'Categoria'] = 'Disco Externo'

# %%
#ver valores con las siguientes dos cadenas estrictamente: disco y externo y que no tengan la cadena cable
df[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('externo', case=False) & ~df['Nombre del Producto'].str.contains('cable', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 707  DI1169  Disco Externo Toshiba Canvio 2tb Black Usb 3.0...       2.0
#
#      Costo total     Ganancia  Ganancia prom. %  Venta total Categoria
# 707       211.94  324765.8063          153245.0     325000.0     Disco

# %%
#A este valor cmabiar su categoria a Discos Externo
df.loc[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('externo', case=False) & ~df['Nombre del Producto'].str.contains('cable', case=False), 'Categoria'] = 'Disco Externo'

# %%
#ver valores que tengan estrictamente las siguientes dos cadenas: disco y cable
df[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('cable', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 135   DI11610  CARCASA EXTERNA PARA DISCO RIGIDO 2.5 CON CABL...       9.0
# 673    AD2145  CABLE ADAPTADOR DISCO SATA EXTERNO A USB 3,0 /...       2.0
# 694    09-038  Cable USB a USB 3.0 Disco Externo Cable 1 Metr...       2.0
# 1078  TR-1005  Cable Sata Power Molex Discos Rigidos 4 Pin No...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %   Venta total  \
# 135         66.60  115726.406550          173774.0  115799.99955
# 673         13.48   24385.104600          180909.0   24400.00000
# 694          7.52   14890.905200          198038.0   14900.00440
# 1078         0.31    2499.620148          806352.0    2500.00000
#
#           Categoria
# 135   Disco Externo
# 673           Disco
# 694           Disco
# 1078          Disco

# %%
#de estos valores cambiar su categoria a 'Cable' si ademas no tienen la cadena Carcasa
df.loc[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('cable', case=False) & ~df['Nombre del Producto'].str.contains('carcasa', case=False), 'Categoria'] = 'Cable'

# %%
#ver valores que tengan estrictamente la cadena disco y servicio tecnico
df[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('servicio tecnico', case=False)]
# Out:
#      Código                      Nombre del Producto  Cantidad  Costo total  \
# 854  SE5315  SERVICIO TECNICO NOTE INSTALACION DISCO       2.0          0.0
#
#      Ganancia  Ganancia prom. %  Venta total Categoria
# 854      20.0               NaN         20.0     Disco

# %%
#de esos valores cambiar su categoria a 'Servicio Tecnico'
df.loc[df['Nombre del Producto'].str.contains('disco', case=False) & df['Nombre del Producto'].str.contains('servicio tecnico', case=False), 'Categoria'] = 'Servicio Tecnico'

# %%
#ver valores con la cadena ajedrez
df[df['Nombre del Producto'].str.contains('ajedrez', case=False)]
# Out:
#     Código                       Nombre del Producto  Cantidad  Costo total  \
# 742  JU998  JUEGO DE AJEDREZ TABLERO MAGNETICO 3881A       2.0         15.4
#
#       Ganancia  Ganancia prom. %  Venta total  \
# 742  27781.366          180419.0      27800.0
#
#                                     Categoria
# 742  JUEGO DE AJEDREZ TABLERO MAGNETICO 3881A

# %%
#cambiar ese producto  a 'Juguete'
df.loc[df['Nombre del Producto'].str.contains('ajedrez', case=False), 'Categoria'] = 'Juguete'

# %%
#ver valores con la cadena hd externo
df[df['Nombre del Producto'].str.contains('hd externo', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 732  DI8228  HD EXTERNO 1TB PORTABLE WD ELEMENTS BLACK USB ...       2.0
#
#      Costo total      Ganancia  Ganancia prom. %   Venta total  \
# 732       141.44  217843.70445          154029.0  217999.99565
#
#                                              Categoria
# 732  HD EXTERNO 1TB PORTABLE WD ELEMENTS BLACK USB ...

# %%
#cambiar la categoria de ese producto a 'Disco Externo'
df.loc[df['Nombre del Producto'].str.contains('hd externo', case=False), 'Categoria'] = 'Disco Externo'

# %%
#ve valores con la cadena bluetooth auto
df[df['Nombre del Producto'].str.contains('bluetooth auto', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 600  AC7268  Transmisor Inalambrico Bluetooth Auto Manos Li...       3.0
#
#      Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 600        11.31  26986.325342          238627.0      27000.0
#
#                                              Categoria
# 600  Transmisor Inalambrico Bluetooth Auto Manos Li...

# %%
#cambiar la categoria de ese producto a 'Accesorio'
df.loc[df['Nombre del Producto'].str.contains('bluetooth auto', case=False), 'Categoria'] = 'Accesorio'

# %%
#ver valores con la cadena cabezal
df[df['Nombre del Producto'].str.contains('cabezal', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 58     CA6170  CABEZAL CARGADOR 220V XAEA OPTIMUM 5A 45w (USB...      18.0
# 139    CA6137  Cargador Cabezal Malibu Tipo C 30w PD769 Carga...       9.0
# 158   CA71103           CABEZAL PARA IPHONE 20W TIPO C MU7U2LL/A       8.0
# 302   CA71117  CARGADOR CABEZAL SEND S01+ UN PUERTO USB 5v 3....       5.0
# 1050   IB-611  CARGADOR CABEZAL ADAPTADOR PUERTO USB + TYPE C...       1.0
# 1051    CA126  CARGADOR CABEZAL SAMSUNG 25W SUPER RAPIDA USB ...       1.0
# 1052   CA6169  CARGADOR CABEZAL SAMSUNG 65W SUPER RAPIDA / SA...       1.0
# 1053  CAR1502                     CARGADOR CABEZAL SAMSUNG TURBO       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 58          73.80  197410.707600          267515.0  197500.0056
# 139         44.38   91246.258596          205623.0   91300.0000
# 158        120.96  233753.638400          193270.0  233900.0000
# ...

# %%
#cambiar la categoria de ese producto a 'Cargador'
df.loc[df['Nombre del Producto'].str.contains('cabezal', case=False), 'Categoria'] = 'Cargador'

# %%
#ver cantidad de valores en la categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                             215
# Modulo                                                                  125
# Bateria                                                                 115
# Auricular                                                               102
# Vidrio Glass                                                             96
#                                                                        ...
# Antena Externa Adaptador Usb Wifi Placa Red Lan 802 N Gb                  1
# SOPLADOR RL043A RELIFE                                                    1
# Accesorio Disco                                                           1
# BASTON SELFI STICK 3 GEN. QUALITY BLUETOOH 78 CM CON CABLE                1
# Antena Tda 4k 5.0 Dbi Con Cable De 5 Mts Interior Y Exterior SG-3003      1
# Name: count, Length: 75, dtype: int64

# %%
#ver valores con la cadena antena
df[df['Nombre del Producto'].str.contains('antena', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 270     CO953       PLACA USB/WIFI 150M CON ANTENA 5DBI DNW150U2       6.0
# 387     CO949   EXTENSOR / REPETIDOR KANJI KJN-RP4200B 4 ANTENAS       4.0
# 467     C8114  Antena Externa Adaptador Usb Wifi Placa Red La...       3.0
# 569     CO952  PLACA USB/WIFI 150M CON ANTENA DN-W150U3 or 13...       3.0
# 582    CO8132  ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI...       3.0
# 851     CO946  ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...       2.0
# 951   NG-Uw06  Adaptador Inalambrico Wifi Usb Red Noga NG-Uw0...       1.0
# 1417    CO958        REPETIDOR WIFI 2 ANTENAS DINAX / REPRP4200C       1.0
# 1418   CO8130         ROUTER TP-LINK ARCHER C50 AC1200 4 ANTENAS       1.0
# 1535    TV598  Antena Tda 4k 5.0 Dbi Con Cable De 5 Mts Inter...       0.0
#
#       Costo total       Ganancia  Ganancia prom. %   Venta total  \
# 270         30.00   56766.850000          189233.0   56800.00000
# ...

# %%
#ver valores que tengna estrictamente la cadena antena como primera caden a
df[df['Nombre del Producto'].str.contains('^antena', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 467   C8114  Antena Externa Adaptador Usb Wifi Placa Red La...       3.0
# 1535  TV598  Antena Tda 4k 5.0 Dbi Con Cable De 5 Mts Inter...       0.0
#
#       Costo total     Ganancia  Ganancia prom. %  Venta total  \
# 467         11.88  28485.64161          239799.0      28500.0
# 1535         0.00      0.00000               NaN          0.0
#
#                                               Categoria
# 467   Antena Externa Adaptador Usb Wifi Placa Red La...
# 1535  Antena Tda 4k 5.0 Dbi Con Cable De 5 Mts Inter...

# %%
#cambiar la categoria de esos productos a 'Conectividad'
df.loc[df['Nombre del Producto'].str.contains('^antena', case=False), 'Categoria'] = 'Conectividad'

# %%
#cambiar la categoria de los productos con la cadena seña por arreglo a Servicio Tecnico
df.loc[df['Nombre del Producto'].str.contains('seña por arreglo', case=False), 'Categoria'] = 'Servicio Tecnico'

# %%
#ver valores con la cadena case disco
df[df['Nombre del Producto'].str.contains('case disco', case=False)]
# Out:
#     Código                       Nombre del Producto  Cantidad  Costo total  \
# 376  D8211  CASE DISCO 3.0 Seisa Tranparente Dn-k209       4.0         16.2
#
#          Ganancia  Ganancia prom. %  Venta total        Categoria
# 376  31980.399658          197431.0      32000.0  Accesorio Disco

# %%
#a los valores con la cadena case disco 3.0 cambiar su categoria a Disco Interno
df.loc[df['Nombre del Producto'].str.contains('case disco 3.0', case=False), 'Categoria'] = 'Disco Interno'

# %%
#ver valores con la cadena soplador
df[df['Nombre del Producto'].str.contains('soplador', case=False)]
# Out:
#     Código     Nombre del Producto  Cantidad  Costo total    Ganancia  \
# 438  H9061  SOPLADOR RL043A RELIFE       4.0        11.96  21194.9884
#
#      Ganancia prom. %  Venta total               Categoria
# 438          177237.0     21209.46  SOPLADOR RL043A RELIFE

# %%
#cambiar la categoria de esos productos a 'Herramienta'
df.loc[df['Nombre del Producto'].str.contains('soplador', case=False), 'Categoria'] = 'Herramienta'

# %%
#ver valores con la cadena baston
df[df['Nombre del Producto'].str.contains('baston', case=False)]
# Out:
#     Código                                Nombre del Producto  Cantidad  \
# 292  A7217  BASTON SELFI STICK 3 GEN. QUALITY BLUETOOH 78 ...       5.0
#
#      Costo total     Ganancia  Ganancia prom. %  Venta total  \
# 292         15.7  33981.00742          216461.0      34000.0
#
#                                              Categoria
# 292  BASTON SELFI STICK 3 GEN. QUALITY BLUETOOH 78 ...

# %%
#cambiar la categoria de esos productos a 'Accesorio'
df.loc[df['Nombre del Producto'].str.contains('baston', case=False), 'Categoria'] = 'Accesorio'

# %%
#ver fila con mas numero en su columna Cantidad
df[df['Cantidad'] == df['Cantidad'].max()]
# Out:
#      Código Nombre del Producto  Cantidad  Costo total      Ganancia  \
# 1554    NaN                 nan    6294.0    166296.86  1.294925e+08
#
#       Ganancia prom. %   Venta total Categoria
# 1554               NaN  1.308388e+08  Joystick

# %%
#modificar la cattegoria de esa fila como : Sin Categoria
df.loc[df['Cantidad'] == df['Cantidad'].max(), 'Categoria'] = 'Sin Categoria'

# %%
#eliminar estas filas
df = df.dropna(subset=['Cantidad'])

# %%
#pasar a Int la columna Cantidad
df['Cantidad'] = df['Cantidad'].astype(int)
# Out:
# C:\Users\tm\AppData\Local\Temp\ipykernel_6980\985100368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cantidad'] = df['Cantidad'].astype(int)

# %%
#ver fila con el Nombre del Producto con mayor cantidad
df[df['Cantidad'] == df['Cantidad'].max()]
# Out:
#      Código Nombre del Producto  Cantidad  Costo total      Ganancia  \
# 1554    NaN                 nan      6294    166296.86  1.294925e+08
#
#       Ganancia prom. %   Venta total      Categoria
# 1554               NaN  1.308388e+08  Sin Categoria

# %%
#redondear la columna ganancia a 0 decimales y transformar a int
df['Ganancia'] = df['Ganancia'].round(0)
df['Ganancia'] = df['Ganancia'].astype(int)
# Out:
# C:\Users\tm\AppData\Local\Temp\ipykernel_6980\1885528244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ganancia'] = df['Ganancia'].round(0)
# C:\Users\tm\AppData\Local\Temp\ipykernel_6980\1885528244.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ganancia'] = df['Ganancia'].astype(int)

# %%
#Redondear ganancia prom. % a 5 decimales
df['Ganancia Prom. %'] = df['Ganancia prom. %'].round(5)
# Out:
# C:\Users\tm\AppData\Local\Temp\ipykernel_6980\1326243431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ganancia Prom. %'] = df['Ganancia prom. %'].round(5)

# %%
#Redondear la columna 'Venta total' a 0 decimales y transformar a int
df['Venta total'] = df['Venta total'].round(0)
df['Venta total'] = df['Venta total'].astype(int)
# Out:
# C:\Users\tm\AppData\Local\Temp\ipykernel_6980\3970242243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Venta total'] = df['Venta total'].round(0)
# C:\Users\tm\AppData\Local\Temp\ipykernel_6980\3970242243.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Venta total'] = df['Venta total'].astype(int)

# %%
#ver valores con la cadena parlante y la cadena buzzer estrictamente
df[df['Nombre del Producto'].str.contains('parlante', case=False) & df['Nombre del Producto'].str.contains('buzzer', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 148    P106  Parlante Buzzer Altavoz MOTO G7 POWER / G7 PLA...         9
# 1382   P105                Parlante Buzzer Altavoz GRAND PRIME         1
# 1383   P129       Parlante Buzzer Altavoz MOTO G9 PLAY CAPSULA         1
# 1384   P109  Parlante Buzzer Altavoz SAM A10/a20/a30/a40/a5...         1
# 1385   P119                   Parlante Buzzer Altavoz Sam A10s         1
#
#       Costo total  Ganancia  Ganancia prom. %  Venta total Categoria  \
# 148          0.02     32800      1.640000e+08        32800  Parlante
# 1382         0.11      1000      9.089910e+05         1000  Parlante
# 1383         1.29     19998      1.550290e+11        20000  Parlante
# 1384         0.46      2099      4.564220e+05         2100  Parlante
# 1385         0.57      2099      3.683210e+05         2100  Parlante
#
#       Ganancia Prom. %
# 148       1.640000e+08
# 1382      9.089910e+05
# 1383      1.550290e+11
# ...

# %%
#cambiar la cateogira de ese producto a Repuesto Parlante
df.loc[df['Nombre del Producto'].str.contains('parlante', case=False) & df['Nombre del Producto'].str.contains('buzzer', case=False), 'Categoria'] = 'Repuesto Parlante Celular'

# %%
#ver valores con la cadena parlante
df[df['Nombre del Producto'].str.contains('parlante', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 148       P106  Parlante Buzzer Altavoz MOTO G7 POWER / G7 PLA...         9
# 331   PA131159  PARLANTE PORTATIL RADIO Y LECTOR TARJETA YX-07...         5
# 391     CA6172  FUENTE UNIVERSAL 9V 1,5A DOBLE FICHA  ROUTER /...         4
# 572     PA6475                Parlante pc Genius Usb SP-Q180 AZUL         3
# 573     PA6464     Parlantes Genius Sp Hf280 Usb 6w Wooden Madera         3
# 815    PA27130              PARLANTE BLUETOOTH DINAX DE 3" REGGAE         2
# 816    PA11821   PARLANTE DINAX 2.0 GAMER / BARRA DX-SPLITB C/LED         2
# 817   PA645321                    PARLANTE JBL BLUETOOTH GO3 BLUE         2
# 818   PA131160  PARLANTE VELADOR BLUETOOTH CARGADOR INALAMBRIC...         2
# 832   PA131142                 Parlante JBL BLUETOOH FLIP 6 BLACK         2
# 833   PA131141                Parlante JBL BLUETOOH FLIP 6 BLUE 2         2
# ...

# %%
#Eliminar la columna 'Ganancia prom. %'
df = df.drop(columns=['Ganancia prom. %'])

# %%
#guardar df como excel
df.to_excel('Reporte de ventas por articulos MOD 3.xlsx', index=False)
