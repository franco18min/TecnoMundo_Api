# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#leer com df el archivo excel : Reporte de ventas por articulos MOD
df = pd.read_excel('Reporte de ventas por articulos MOD.xlsx')

# %%
#str columna 'Categoria' y 'Nombre del Producto'
df['Categoria'] = df['Categoria'].astype(str)
df['Nombre del Producto'] = df['Nombre del Producto'].astype(str)

# %%
#ver valores con la cadena badeja sim en la columna "Nombre del Producto"
df[df['Nombre del Producto'].str.contains('bandeja sim', case=False)]
# Out:
#     Código                                Nombre del Producto  Cantidad  \
# 979   B130                         BANDEJA SIM S10 / S10 PLUS       1.0
# 980   B100  BANDEJA SIM SAM A10 / A10S / A20 / A30 / A50 /...       1.0
# 981   B131                                BANDEJA SIM SAM A31       1.0
# 982   B116                BANDEJA SIM SAM S8 / S8 PLUS SYLVER       1.0
#
#      Costo total   Ganancia  Ganancia prom. %  Venta total  \
# 979         0.34  5499.5886      1.617550e+11       5500.0
# 980         0.34  5099.5886      1.499900e+10       5100.0
# 981         0.34  5099.5886      1.499900e+10       5100.0
# 982         0.34  4999.5886      1.470490e+11       5000.0
#
#                                              Categoria
# 979                         BANDEJA SIM S10 / S10 PLUS
# 980  BANDEJA SIM SAM A10 / A10S / A20 / A30 / A50 /...
# 981                                BANDEJA SIM SAM A31
# 982                BANDEJA SIM SAM S8 / S8 PLUS SYLVER

# %%
#Agregar la cadena en la columna categoria la cadena "Badeja SIM" si la columna "Nombre del Producto" contiene la cadena "bandeja sim"
df.loc[df['Nombre del Producto'].str.contains('bandeja sim', case=False), 'Categoria'] = 'Badeja SIM'

# %%
#ver valores que tengna estricamente  la cadena "hub" en la columa nombre del producto
df[df['Nombre del Producto'].str.contains('hub', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 153    AD2136         ADAPTADOR HUB USB CON 4 PUERTOS USB SX-36        8.0
# 395    AD2107              HUB 4 PUERTOS USB 1MTS DINAX DX-HUB1M       4.0
# 615    AD2137  ADAPTADOR HUB 3 EN 1 TIPO-C A HDMI+USB3.0+PD B...       2.0
# 616    AD2140  ADAPTADOR HUB 5 EN 1 TIPO-C A HDMI+USB3.0+PD+P...       2.0
# 617    AD2141  ADAPTADOR HUB 5 EN 1 TIPO-C A SD/TF+USB3.0+USB...       2.0
# 618    AD2142  ADAPTADOR HUB 6 EN 1 TIPO-C A HDMI+SD/TF+USB2....       2.0
# 619     SX-38  ADAPTADOR HUB IPHONE CON 3 PUERTOS USB Y 1 PUE...       2.0
# 735    KQ009H           Hub Usb 3.0 De 4 Puertos Aluminio Kq009H       2.0
# 1167    AD299                  HUB TIPO C SEISA BYL-2103T 5 IN 1       1.0
# 1168   KQ-009  Hub Adaptador Tipo C A Hdmi / Vga / Usb 3.0 / ...       1.0
# 1169   KQ008H                    Hub Usb 3.0 De 4 Puertos Kq008H       1.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "HUB" si la columna "Nombre del Producto" contiene la cadena "hub" y que no tenga las cadenas : adaptador
df.loc[df['Nombre del Producto'].str.contains('hub', case=False) & ~df['Nombre del Producto'].str.contains('adaptador', case=False), 'Categoria'] = 'HUB'

# %%
#ver valores con la cadena lente camara
df[df['Nombre del Producto'].str.contains('lente camara', case=False)]
# Out:
#      Código                      Nombre del Producto  Cantidad  Costo total  \
# 397    L111   LENTE CAMARA IPHONE 11 12 12 Mini X2 U       4.0         0.92
# 524    L114                    LENTE CAMARA IPHONE X       3.0         0.33
# 751    L141               LENTE CAMARA IPHONE 11 PRO       2.0         0.58
# 1204   L139  LENTE CAMARA IPHONE 6 6S 6S PLUS 6 PLUS       1.0         0.06
# 1205   L161               LENTE CAMARA MOTO G8 POWER       1.0         0.11
# 1206   L130         LENTE CAMARA SAM A10 / a20 / a30       1.0         0.11
# 1207   L119           LENTE CAMARA XIAOMI NOTE 8 PRO       1.0         0.23
#
#           Ganancia  Ganancia prom. %  Venta total  \
# 397   14198.888844      1.543380e+11      14200.0
# 524    6499.600700      1.969600e+10       6500.0
# 751    8799.303780      1.517140e+11       8800.0
# 1204   2399.927400      3.999900e+10       2400.0
# 1205   1999.866900      1.818080e+11       2000.0
# 1206   1999.866900      1.818080e+11       2000.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Lente Camara" si la columna "Nombre del Producto" contiene la cadena "lente camara"
df.loc[df['Nombre del Producto'].str.contains('lente camara', case=False), 'Categoria'] = 'Lente Camara'

# %%
#ver valores que tengan estrictamente como primera cadena, la cadena "celular" en la columan nombre del producto
df[df['Nombre del Producto'].str.contains('^celular', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 248   CE8153    CELULAR NOKIA 106 Dual SIM 4 MB RAM GRIS OSCURO       6.0
# 1094  CE8123      Celular Motorola Moto G13 64gb / 4gb RAM Gris       1.0
# 1095  CE8107  Celular Motorola Moto G32 128GB / 4GB Ram Plat...       1.0
# 1096  CE9190      Celular Samsung Galaxy A04 32GB/3GB RAM VERDE       1.0
# 1097  CE8130      Celular Samsung Galaxy A04 64GB/4GB RAM Negro       1.0
# 1098  CE8138     Celular Samsung Galaxy A14 128gb/4gb Ram Negro       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 248     104400.00  118676.000000            148.08     259000.0
# 1094        54.22   26734.389269          49328.30      26800.0
# 1095        65.07  359921.265300         774450.00     504000.0
# 1096        29.34  194964.501142         664522.00     195000.0
# 1097        62.90  294923.891000         468898.00     295000.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Celular" en las filas que tengan estrictamente como primera cadena, la cadena "celular" en la columan nombre del producto
df.loc[df['Nombre del Producto'].str.contains('^celular', case=False), 'Categoria'] = 'Celular'

# %%
#ver valores con la cadena pendrive o pen drive
df[df['Nombre del Producto'].str.contains('pendrive|pen drive', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 126   PE2826  Pendrive Patriot 64gb Supersonico Rage Lite Us...      10.0
# 222   PE2822  PENDRIVE KINGSTON 3.2 dtx 128Gb Exodia Negro/A...       7.0
# 271   PE8820  Pen Drive KINGSTON 32GB USB 3.2 DTXM EXODIA M ...       6.0
# 272   PE8816               Pen Drive Sandisk Cruzer Blade 128gb       6.0
# 424   PE2825  Pen Drive HIKSEMI 64Gb M200S Rotary USB 3.0 (6...       4.0
# 425     P885   Pen Drive KINGSTON 32GB USB 3.2 DTX EXODIA NEGRO       4.0
# 834   PE2824              Pendrive Patriot 64gb Push + Usb 3.2        2.0
# 1551  PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 126         65.30  135420.985500          207404.0  135499.9985
# 222         66.05  136340.080300          206440.0  136420.0008
# 271         41.46   73349.833400          176938.0   73400.0000
# ...

# %%
df
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 0     R124132  VIDRIO GLASS SAMSUNG  A02S / A03 / A03 CORE / ...      90.0
# 1      PI3017                       Pilas Boton 3 V Philco 2032       70.0
# 2       D1014  CABLE USB ONLY MOD48 / V8 / 3,1A BLANCO Y NEGR...      55.0
# 3          C6  Pin Carga Sam J7 pro / J7 prime / J5 prime / J...      54.0
# 4       SE966            SERVICIO TECNICO REVISION Y PRESUPUESTO      54.0
# ...       ...                                                ...       ...
# 1550  RC76393  BATERIA SAM A14 / A52 / S20 FE / A52S 100% Ori...      -1.0
# 1551   PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
# 1552      NaN                                                nan       NaN
# 1553      NaN                                                nan       NaN
# 1554      NaN                                                nan    6294.0
#
#       Costo total      Ganancia  Ganancia prom. %   Venta total  \
# ...

# %%
#ver valores con la cadena camara en su nombre
df[df['Nombre del Producto'].str.contains('camara', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 111    CA712086  TRANSFORMADOR FUENTE TIRA DE LED CCTV CAMARAS ...      11.0
# 341      SO5539  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,02...       5.0
# 342      SO5540  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,40...       5.0
# 379   CA1154979  Camara Web Naxido 1080p W9n Full Hd 30fps Con ...       4.0
# 397        L111             LENTE CAMARA IPHONE 11 12 12 Mini X2 U       4.0
# 483      CA1159             CAMARA SMART IP 720P DINAX DX-CAMSMAIP       3.0
# 488     CA11437   Camara De Seguridad Ip 3Mp Seisa IPC-S036 Blanco       3.0
# 513      VI6043  Film Vidrio Templado CAMARA FULL Para Iphone 1...       3.0
# 524        L114                              LENTE CAMARA IPHONE X       3.0
# 698     CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 699     CA11438  Camara De Seguridad IPC-ZAS05 DOBLE LENTE 360 ...       2.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Camara de Seguridad" si la columna "Nombre del Producto" tiene estrictamente la cadena "camara smart"
df.loc[df['Nombre del Producto'].str.contains('camara smart', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
#ver las filas que tengan estrictamente las cadenas camara y interior o exterior
df[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('interior|exterior', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 698   CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 701    CA7431  Camara wifi Ezviz interior inteligente - C6N 1...       2.0
# 1044  CA11436  CAMARA EXTERIOR IP WIFI IMOU Cruiser Se+ 4mp F...       1.0
# 1045   CA7435     CAMARA IP CLOUD TP-LINK TAPO C310 3MP EXTERIOR       1.0
# 1083  CA11445  Camara De Seguridad Ezviz Domo Color Full H8C ...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 698         62.00  119924.980000          193448.0     120000.0
# 701         71.58  131513.393836          183750.0     131600.0
# 1044        65.99  118920.155194          180230.0     119000.0
# 1045        42.69   79948.340183          187298.0      80000.0
# 1083        46.00   89944.340000          195552.0      90000.0
#
#                                               Categoria
# 698                                 Camara de Seguridad
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Camara de Seguridad" si la columna "Nombre del Producto" tiene estrictamente las cadenas camara y interior o exterior
df.loc[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('interior|exterior', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
#ver valores con la cadena espia
df[df['Nombre del Producto'].str.contains('espia', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 1086  CA11432  Camara Mini Espia De Seguridad Wifi Hd Con Mic...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 1086        14.44  29382.526826          203501.0      29400.0
#
#                                               Categoria
# 1086  Camara Mini Espia De Seguridad Wifi Hd Con Mic...

# %%
#Agregar la cadena en la columna categoria la cadena "Camara de Seguridad" si la columna "Nombre del Producto" tiene estrictamente las cadenas "camara" y "espia"
df.loc[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('espia', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
#añadir la cadena "Camara de Seguridad" en la columna categoria si la columna "Nombre del Producto" tiene estrictamente las cadenas camara y interior o exterior
df.loc[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('interior|exterior', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
#Ver valores con la cadena camara web
df[df['Nombre del Producto'].str.contains('camara web', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 379   CA1154979  Camara Web Naxido 1080p W9n Full Hd 30fps Con ...       4.0
# 700        C007           Camara Web 1080p USB Con Microfono C007        2.0
# 1087     CA7430        Camara Web Webcam Xiaomi W88 FULL HD(1080P)       1.0
# 1088     CA7436            Camara web GENIUS Facecam 1000x 720p hd       1.0
#
#       Costo total    Ganancia  Ganancia prom. %  Venta total  \
# 379         38.72  77953.1488          201346.0      78000.0
# 700         21.00  36776.7950          175138.0      36800.0
# 1087        23.23  57971.8917          249577.0      58000.0
# 1088        15.70  27981.0030          178244.0      28000.0
#
#                                         Categoria
# 379                                          Tapa
# 700      Camara Web 1080p USB Con Microfono C007
# 1087  Camara Web Webcam Xiaomi W88 FULL HD(1080P)
# 1088      Camara web GENIUS Facecam 1000x 720p hd

# %%
#Agregar la cadena en la columna categoria la cadena "Camara Web" si la columna "Nombre del Producto" tiene estrictamente la cadena "camara web"
df.loc[df['Nombre del Producto'].str.contains('camara web', case=False), 'Categoria'] = 'Camara Web'

# %%
#ver filas en nombre de producto donde tengan estrictamente como primera cadena la cadena tactil
df[df['Nombre del Producto'].str.contains('^tactil', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 52     R9519                         TACTIL SAM J2 PRIME SYLVER      20.0
# 862   RVG192                           TACTIL  LG K40s NEGRO +O       2.0
# 1456   RT305                           TACTIL LG K4 K120 GRANDE       1.0
# 1457   RT310                          TACTIL SAM J2 PRIME BLACK       1.0
# 1458  RT1003  TACTIL TITAN JZ-1003-FPCV1 / ONTOP ATC7015 FPC...       1.0
# 1477  RT1104  Tactil Samsung Galaxy Tab 3 Lite T113NU CAMARA...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 52          16.00  76980.651050          481150.0      77000.0
# 862          8.78  10889.364155          124046.0      10900.0
# 1456         0.57   1999.309361          350777.0       2000.0
# 1457         0.80   2499.033105          312400.0       2500.0
# 1458         4.39   7495.143550          170743.0       7500.0
# 1477        12.56  16686.124429          132862.0      16700.0
#
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Pantalla Tactil" si enla columna "Nombre del Producto" tiene estrictamente la cadena "tactil"
df.loc[df['Nombre del Producto'].str.contains('^tactil', case=False), 'Categoria'] = 'Tactil'

# %%
#ver valores con la cadena combo
df[df['Nombre del Producto'].str.contains('combo', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 106    TE5840  KIT COMBO TECLADO Y MOUSE INALMBRICO 2.4G SLIM...      11.0
# 1158  TE11115                        GAMING COMBO 4 EN 1 NKB-405       1.0
# 1188   LU1998              KIT COMBO TIRA DE LED RGB LED-Y3528RD       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 106        138.16  215447.368721          158122.0     218600.0
# 1158        14.59   41983.883525          359736.0      52500.0
# 1188         8.86   15889.279400          224223.0      19875.0
#
#                                   Categoria
# 106                       Kit Teclado Mouse
# 1158            GAMING COMBO 4 EN 1 NKB-405
# 1188  KIT COMBO TIRA DE LED RGB LED-Y3528RD

# %%
#Agregar la cadena en la columna categoria la cadena "Kit gaming" si la columna "Nombre del Producto" contiene estrictamente la cadena "gaming" y "combo"
df.loc[df['Nombre del Producto'].str.contains('gaming', case=False) & df['Nombre del Producto'].str.contains('combo', case=False), 'Categoria'] = 'Kit Gaming'

# %%
#agregar la cadena "Luces" en la columna categoria si la columna "Nombre del Producto" contiene la cadena "KIT COMBO TIRA DE LED RGB LED-Y3528RD"
df.loc[df['Nombre del Producto'].str.contains('KIT COMBO TIRA DE LED RGB LED-Y3528RD', case=False), 'Categoria'] = 'Luces'

# %%
#ver filas con cantidad de valores
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    211
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# Pad Liso De Caucho Y Corcho Cmp213                               1
# PLACA USB/WIFI 150M CON ANTENA DN-W150U3 or 135145               1
# PLACA DE SONIDO USB DX-PLSON71 DINAX                             1
# NEON RGB KIT LED-3535NH72TZ-12V-RGB 5M                           1
# Pendrive Kingston DataTraveler SE9 DTSE9H 32GB 2.0 plateado      1
# Name: count, Length: 168, dtype: int64

# %%
#ver valores con la cadena botones
df[df['Nombre del Producto'].str.contains('boton', case=False)]
# Out:
#       Código           Nombre del Producto  Cantidad  Costo total  \
# 1     PI3017  Pilas Boton 3 V Philco 2032       70.0        32.20
# 1022   RB101           BOTON HOME IPHONE 7       1.0         0.09
#
#           Ganancia  Ganancia prom. %  Venta total            Categoria
# 1     73911.053000      2.295580e+05    73950.015                 Pila
# 1022  12999.889498      1.444430e+12    13000.000  BOTON HOME IPHONE 7

# %%
#ver valores con la cadena flex
df[df['Nombre del Producto'].str.contains('flex', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 308      H9060                           DOCK FLEX TEST (TIPO C)        5.0
# 390       F393                   FLEX INTERCONEXION SAM A50 NO. 2       4.0
# 436     SE5312                   SERVICIO TECNICO REPARACION FLEX       4.0
# 507       FC03                      FLEX DE CARGA IPHONE 6S WHITE       3.0
# 508       FC42            FLEX DE CARGA IPHONE 8 PLUS WHITE/BLACK       3.0
# 509       F404                     FLEX INTERCONEXION SAMSUNG A52       3.0
# 628   AU127145  AURICULAR JBL WAVE FLEX TRULY WIRELESS NEGRO (...       2.0
# 706      H9058                             DOCK FLEX TEST (Micro)       2.0
# 724       F403                   FLEX INTERCONEXION MOTO G9 POWER       2.0
# 725       F401  FLEX INTERCONEXION SAM A22 4G - A225 / A32 - A325       2.0
# 726       F400                        FLEX INTERCONEXION SAM A30S       2.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Flex" si la columna "Nombre del Producto" contiene estrictamente la cadena "boton home" o "boton encendido"
df.loc[df['Nombre del Producto'].str.contains('boton home|boton encendido', case=False), 'Categoria'] = 'Flex'

# %%
#ver valores con la cadena touch
df[df['Nombre del Producto'].str.contains('touch', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 599     RT1001  Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FP...       3.0
# 885    R101118  Touch Mas Simple 8 pulgadas / L201190610 06.38...       2.0
# 908     RT1066                4B1 Touch Philco TP7A1I / PB70A2229       1.0
# 1120   LU19104  ESPEJO RECTANGULAR TOUCH CON LUZ LED DINAX / D...       1.0
# 1211  VIR-4556  Lampara De Escritorio Usb Oficina Led Velador ...       1.0
# 1495    RT1002  Touch 3G / 0101-T 2014.02, c184104a1-fpc738dr,...       1.0
# 1496    RT1137   Touch Alcatel 8067 / TCL LT7 M / wj1901-fpc v5.0       1.0
# 1497    RT1083  Touch C145254K1-DRFPC391T-V2.0 / MF-817-101F-3...       1.0
# 1498    RT1100  Touch Samsung Tab 3 SM-T111 (solo BLANCO) RANU...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 599         11.31  18487.511986      1.634720e+05      18500.0
# 885         29.50  60967.392409      2.066800e+05      61000.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Tactil" si la columna "Nombre del Producto" contiene la cadena "touch" y no tiene ninguna de las siguientes cadenas: lampara, espejo
df.loc[df['Nombre del Producto'].str.contains('touch', case=False) & ~df['Nombre del Producto'].str.contains('lampara|espejo', case=False), 'Categoria'] = 'Tactil'

# %%
#Ver valores con la cadena router
df[df['Nombre del Producto'].str.contains('router', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 391   CA6172  FUENTE UNIVERSAL 9V 1,5A DOBLE FICHA  ROUTER /...       4.0
# 582   CO8132  ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI...       3.0
# 851    CO946  ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...       2.0
# 1418  CO8130         ROUTER TP-LINK ARCHER C50 AC1200 4 ANTENAS       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 391          8.80   25989.352000          295355.0   26000.0000
# 582         78.73  163413.009771          207572.0  163500.0096
# 851         22.60   58972.650685          260962.0   59000.0000
# 1418        29.00   64967.955000          224038.0   65000.0000
#
#                                               Categoria
# 391                                         Herramienta
# 582   ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI...
# 851   ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...
# ...

# %%
#ver valores con la cadena tp-link
df[df['Nombre del Producto'].str.contains('tp-link', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 434     CO8138  Receptor USB NANO Wireless WIFI AC600 Dual ban...       4.0
# 533      C8118  Mini Adaptador USB Wifi tp-link TL-WN823N 300M...       3.0
# 582     CO8132  ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI...       3.0
# 636     CO8137  Adaptador Nano USB a Wireless 150 Mbps Mercusy...       2.0
# 715   EXTRE200  EXTENSOR DE RANGO Tp-Link Re200 Dual Band 2.4G...       2.0
# 840      C8110  Placa de Red PCI-E 300N 2x 2Dbi Tp-Link TL-WN8...       2.0
# 954     AD722N  Adaptador Placa De Red Usb Inalambrico Tp-link...       1.0
# 1045    CA7435     CAMARA IP CLOUD TP-LINK TAPO C310 3MP EXTERIOR       1.0
# 1418    CO8130         ROUTER TP-LINK ARCHER C50 AC1200 4 ANTENAS       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 434         72.00  129820.440000          180317.0  129900.0000
# 533         35.37   62960.924550          178017.0   63000.0084
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Router" si la columna "Nombre del Producto" tiene la cadena router y no tiene las cadenas: fuente
df.loc[df['Nombre del Producto'].str.contains('router', case=False) & ~df['Nombre del Producto'].str.contains('fuente', case=False), 'Categoria'] = 'Router'

# %%
#ver valores con la cadena smartwatch, smart watch, reloj
df[df['Nombre del Producto'].str.contains('smartwatch|smart watch|reloj', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 206      C7164            Cargador Reloj Xiaomi Mi Band 5 / 6 / 7       7.0
# 213    RE11742                MALLA REPUESTO PARA RELOJ 22mm AZUL       7.0
# 704     RE7756                       Cargador USB Reloj SAM FIT 2       2.0
# 755     RE7730             MALLA REPUESTO PARA RELOJ 20mm COLORES       2.0
# 756    REL2013  MALLA REPUESTO PARA RELOJ MI BAND 5 / BAND 6 C...       2.0
# 849     RE9472           RELOJ INTELIGENTE IMILAB W02 1,85" Negro       2.0
# 1215   RE11745                MALLA REPUESTO PARA RELOJ 20mm GRIS       1.0
# 1412    RE9483  RELOJ DESPERTADOR C/CALENDARIO/TEMPERATURA DS-...       1.0
# 1413    RE9485          RELOJ DESPERTADOR CARGA INALAMBRICA AY-21       1.0
# 1414    RE7753       RELOJ INTELIGENTE SMARTWATCH W17 PRO - BLACK       1.0
# 1415  RE775416           RELOJ KIESLECT SMARTWATCH CALLING KR PRO       1.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Smartwatch" si la columna "Nombre del Producto" contiene estrictamente la cadena smartwatch, smart watch, reloj y sin las cadenas: malla y cargador
df.loc[df['Nombre del Producto'].str.contains('smartwatch|smart watch|reloj', case=False) & ~df['Nombre del Producto'].str.contains('malla|cargador', case=False), 'Categoria'] = 'Smartwatch'

# %%
#Agregar la cadena en la columna categoria la cadena "Herramienta" si la columna "Nombre del Producto" contiene estrictamente la cadena: base separadora, hoja de puntos, botella plastica
df.loc[df['Nombre del Producto'].str.contains('base separadora|hoja de puntos|botella plastica', case=False), 'Categoria'] = 'Herramienta'

# %%
#ver valores con la cadena ariculares
df[df['Categoria'].str.contains('Ariculares BT Skullcandy Jib True 2 Con Microfono Gris S1JTW-P744', case=False)]
#cambiar valor a Auricular
df.loc[df['Categoria'].str.contains('Ariculares BT Skullcandy Jib True 2 Con Microfono Gris S1JTW-P744', case=False), 'Categoria'] = 'Auricular'

# %%
#ver valores con la cadena pendrive, pendrive
df[df['Nombre del Producto'].str.contains('pendrive|pen drive', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 126   PE2826  Pendrive Patriot 64gb Supersonico Rage Lite Us...      10.0
# 222   PE2822  PENDRIVE KINGSTON 3.2 dtx 128Gb Exodia Negro/A...       7.0
# 271   PE8820  Pen Drive KINGSTON 32GB USB 3.2 DTXM EXODIA M ...       6.0
# 272   PE8816               Pen Drive Sandisk Cruzer Blade 128gb       6.0
# 424   PE2825  Pen Drive HIKSEMI 64Gb M200S Rotary USB 3.0 (6...       4.0
# 425     P885   Pen Drive KINGSTON 32GB USB 3.2 DTX EXODIA NEGRO       4.0
# 834   PE2824              Pendrive Patriot 64gb Push + Usb 3.2        2.0
# 1551  PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 126         65.30  135420.985500          207404.0  135499.9985
# 222         66.05  136340.080300          206440.0  136420.0008
# 271         41.46   73349.833400          176938.0   73400.0000
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Pendrive" si la columna "Nombre del Producto" contiene estrictamente la cadena pendrive, pendrive
df.loc[df['Nombre del Producto'].str.contains('pendrive|pen drive', case=False), 'Categoria'] = 'Pendrive'

# %%
#ver filas que tengan estrictamente la cadena serv tec o servicio tecnico
df[df['Nombre del Producto'].str.contains('serv tec|servicio tecnico', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 4      SE966            SERVICIO TECNICO REVISION Y PRESUPUESTO      54.0
# 14    SE5320             SERVICIO TECNICO INSTALACION DE MODULO      37.0
# 20    SE5318                    SERVICIO TECNICO REPARACION FPC      30.0
# 29    SE5313                SERVICIO TECNICO SECADO Y RESOLDADO      28.0
# 42    SE5314         SERVICIO TECNICO NOTE INSTALACION SOFTWARE      25.0
# 87    SE5311              SERVICIO TECNICO SOFTWARE C/G CELULAR      13.0
# 151   SE5323                SERVICIO TECNICO NOTE MANTENIMIENTO       9.0
# 276   SE5310    SERVICIO TECNICO SOFTWARE ACTUALIZACION CELULAR       6.0
# 337   SE5317                    SERVICIO TECNICO SOFTWARE RE/GB       5.0
# 435   SE5321                 SERVICIO TECNICO MANTENIMIENTO PS4       4.0
# 436   SE5312                   SERVICIO TECNICO REPARACION FLEX       4.0
# 584     S961                                       SERV TEC PIN       3.0
# ...

# %%
#añadir la cadena "Servicio Tecnico" en la columna categoria si la columna "Nombre del Producto" tiene estrictamente la cadena serv tec o servicio tecnico
df.loc[df['Nombre del Producto'].str.contains('serv tec|servicio tecnico', case=False), 'Categoria'] = 'Servicio Tecnico'

# %%
#ver cantidad de valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      103
# Vidrio Glass                                                    96
#                                                               ...
# PLACA USB/WIFI 150M CON ANTENA DN-W150U3 or 135145               1
# PLACA DE SONIDO USB DX-PLSON71 DINAX                             1
# NEON RGB KIT LED-3535NH72TZ-12V-RGB 5M                           1
# Lector De Memorias Sd Micro Sd A Usb                             1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 140, dtype: int64

# %%
#ver valores que tengan estrictamente la cadena conversor
df[df['Nombre del Producto'].str.contains('conversor', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 48    AD7052      CONVERSOR HDMI A VGA CON CABLE AUDIO SM-C7819      21.0
# 201   AD2135     CONVERSOR DE AUDIO OPTICO A RCA AUDIO SM-C7812       7.0
# 252   AD7051  Conversor Display Port A a HDMI Full HD 1080p ...       6.0
# 1070   A7026  CONVERSOR VGA A HDMI CON AUDIO Y USB (CABLE) 1244       1.0
# 1103  AD7078  Conversor Gamer Para Teclado Y Mouse A Celular...       1.0
# 1104  AD7091  Conversor Rca Audio Y Video AV A Hdmi 1080p AV...       1.0
# 1105  AD7072    Conversor de VGA + Audio a HDMI Activo VGA2HDMI       1.0
# 1320   A7023  NISUTA Conversor Adaptador De Usb A 2 Ps2 NS-C...       1.0
# 1543   A7034  Conversor Hdmi A Rca Audio Y Video AV 1080p HD...       0.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 48          71.40  156313.606000          218948.0  156400.0000
# 201         41.22   76850.123800          188401.0   77700.0000
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Conversor" si la columna "Nombre del Producto" contiene estrictamente la cadena conversor y no tiene la cadena nisuta
df.loc[df['Nombre del Producto'].str.contains('conversor', case=False) & ~df['Nombre del Producto'].str.contains('nisuta', case=False), 'Categoria'] = 'Conversor'

# %%
#ver valores con la cadena pad
df[df['Categoria'].str.contains('Pad', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 41       F6843           MOUSE PAD ERGONOMICO CON GEL CDTEK NEGRO      25.0
# 267      PA130  Mouse Pad Escritorio Home Office Borde Bordado...       6.0
# 398      AC171  Lapiz optico Pen Stylus JAZAK WK24 / Compatibl...       4.0
# 561    PA15524        Mouse Pad Gamer NOGA ST-G36 XL 920 x 294 MM       3.0
# 571     CMP213                 Pad Liso De Caucho Y Corcho Cmp213       3.0
# 766     FU6823            MOUSE PAD ERGONOMICO CON GEL CDTEK AZUL       2.0
# 808   FU687153  Mouse Pad Gamer GLADIUS XXL Netmak 80x30 NM-GL...       2.0
# 809     FU6827  Mouse Pad Gamer Gladius NETMAK NM-GLADIUS 30 X...       2.0
# 810     M10831                  Mouse Pad Redragon P006a Kunlun L       2.0
# 1316    M10832                   Mouse Pad Redragon P003 Suzaku U       1.0
# 1317    M10834                    Mouse Pad Redragon P031 Flick L       1.0
# ...

# %%
#ver valores que tengan estrictamente como primera cadena , la cadena pad
df[df['Nombre del Producto'].str.contains('^pad', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 414   HE18493  PAD TERMICO URANUS TP-U1 50X50X1.0MM 12W/MK AL...       4.0
# 571    CMP213                 Pad Liso De Caucho Y Corcho Cmp213       3.0
# 814   HE89235                 PAD Para plancha de calor - SS004s       2.0
# 1380   CMP833  Pad Gamer Y Oficina De Caucho Y Corcho 80X30Cm...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 414          7.52  18490.900800          245911.0      18500.0
# 571          6.15  14992.558500          243802.0      15000.0
# 814          3.52  12195.745662          346491.0      12200.0
# 1380         4.87  11994.107300          246307.0      12000.0
#
#                                               Categoria
# 414                                         Herramienta
# 571                  Pad Liso De Caucho Y Corcho Cmp213
# 814                                         Herramienta
# ...

# %%
#agregar la cadena mouse pad en la columna categoria, si la columna "Nombre del Producto" tiene estrictamente la cadena pad y si en su columna de caegoria no tiene la cadena Herramienta
df.loc[df['Nombre del Producto'].str.contains('^pad', case=False) & ~df['Categoria'].str.contains('Herramienta', case=False), 'Categoria'] = 'Mouse Pad'

# %%
#ver valores con la cadena lapiz
df[df['Nombre del Producto'].str.contains('lapiz', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 141    AC169  Lapiz Optico Doble Punta Para Smartphone Table...       9.0
# 211   AC7258                             Lapiz optico R06 METAL       7.0
# 398    AC171  Lapiz optico Pen Stylus JAZAK WK24 / Compatibl...       4.0
# 504  HE89227  Estacion De Soldado Lapiz Cautin Con Regulador...       3.0
# 526    AC172         Lapiz optico TARGUS MAGNETICO 5" AMM168GLX       3.0
#
#      Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 141         7.20   16192.044000          224900.0      16200.0
# 211        58.45  100735.409218          172355.0     100800.0
# 398        58.40   95535.468000          163599.0      95600.0
# 504        71.58  141220.909247          197302.0     141300.0
# 526        17.70   28680.441500          162047.0      28700.0
#
#                                              Categoria
# 141                                        Herramienta
# ...

# %%
#agregar la cadena "Lapiz" en la columna categoria si la columna "Nombre del Producto" contiene estrictamente la cadena lapiz y si en su columna categoria no tiene la cadena Herramienta
df.loc[df['Nombre del Producto'].str.contains('lapiz', case=False) & ~df['Categoria'].str.contains('Herramienta', case=False), 'Categoria'] = 'Lapiz'

# %%
#para el producto con el codigo AC169 agregar la cadena "Lapiz" en la columna Lapiz
df.loc[df['Código'] == 'AC169', 'Categoria'] = 'Lapiz'

# %%
#ver valores con que tengan la cadena smart
df[df['Nombre del Producto'].str.contains('smart', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 141      AC169  Lapiz Optico Doble Punta Para Smartphone Table...       9.0
# 483     CA1159             CAMARA SMART IP 720P DINAX DX-CAMSMAIP       3.0
# 491     CA6135  Cargador V8 Micro Malibu RT-714A Smart Fast 3....       3.0
# 743    JO11382  Joystick Inalambrico Bt / Nintendo Switch / PC...       2.0
# 1049    CA7179  CARGADOR AUTO TURBO SEND CARGA RAPIDA  USB TIP...       1.0
# 1118    AS1522      ENCHUFE INTELIGENTE WIFI SMART PLUG SA-014 GB       1.0
# 1212    LU8050   Lamparita Smart Nexxt RGB Wifi 220V Dicroiica x3       1.0
# 1260      P635  Mini Teclado Only Smart Tv Bluetooth Retroilum...       1.0
# 1414    RE7753       RELOJ INTELIGENTE SMARTWATCH W17 PRO - BLACK       1.0
# 1415  RE775416           RELOJ KIESLECT SMARTWATCH CALLING KR PRO       1.0
# 1416    RE9470       RELOJ KIESLECT SMARTWATCH CALLING KS (negro)       1.0
# ...

# %%
#agregar la cadena Smartwatch en la columna cateogir al producto con el codigo RE9494
df.loc[df['Código'] == 'RE9494', 'Categoria'] = 'Smartwatch'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    212
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      103
# Vidrio Glass                                                    96
#                                                               ...
# SPLITTER HDMI 1 A 2 4K / ADP-48006                               1
# SEÑA POR ARREGLO                                                 1
# Radio Retro Am Fm Con Linterna Y Bluetooth Seisa YX-123UBT       1
# RADIO RETRO AM FM CON LINTERNA / BLUETOOTH SEISA YX-119UBT       1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 129, dtype: int64

# %%
#ver valores con la cadena radio
df[df['Nombre del Producto'].str.contains('radio', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 331   PA131159  PARLANTE PORTATIL RADIO Y LECTOR TARJETA YX-07...       5.0
# 580    PA64122  RADIO RETRO AM FM CON LINTERNA / BLUETOOTH SEI...       3.0
# 583    PA64124  Radio Retro Am Fm Con Linterna Y Bluetooth Sei...       3.0
# 844   PA131151  RADIO PORTATIL BLUETOOTH VINTAGE RETRO NEGRO S...       2.0
# 960    AU60229  Auricular Bluetooth NIA Q8-851S Manos Libres E...       1.0
# 1023  PA131144  Barra Sonido Tv o Pc Bluetooth / Sd / Radio / ...       1.0
# 1329    PA6486   PARLANTE MULTIMEDIA RADIO 6,5" NGL-400BT TWS/USB       1.0
# 1381  KTS-1687  Parlante Bt Radio iKaraoke box con microfono I...       1.0
# 1409  PA131135       RADIO PORTATIL POCKET DINAX AM/FM DX-RADIOP1       1.0
# 1419  PA131145  Radio Bluetooth Am / Fm Con Linterna Y Panel S...       1.0
# 1420  PA131158      Radio Retro Am Fm Y Bluetooth Seisa YX-303UBT       1.0
# ...

# %%
#ver valores que tengan estrictamente la cadena radio como primera cadena en su valor
df[df['Nombre del Producto'].str.contains('^radio', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 580    PA64122  RADIO RETRO AM FM CON LINTERNA / BLUETOOTH SEI...       3.0
# 583    PA64124  Radio Retro Am Fm Con Linterna Y Bluetooth Sei...       3.0
# 844   PA131151  RADIO PORTATIL BLUETOOTH VINTAGE RETRO NEGRO S...       2.0
# 1409  PA131135       RADIO PORTATIL POCKET DINAX AM/FM DX-RADIOP1       1.0
# 1419  PA131145  Radio Bluetooth Am / Fm Con Linterna Y Panel S...       1.0
# 1420  PA131158      Radio Retro Am Fm Y Bluetooth Seisa YX-303UBT       1.0
# 1421  PA131157  Radio Retro Vintage Recargable Con Bluetooth K...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 580         36.00   70956.440000          197122.0      71000.0
# 583         66.39  117619.668100          177186.0     117700.0
# 844         28.74   49665.220788          172830.0      49700.0
# 1409         6.66   11991.947146          207107.0      13800.0
# ...

# %%
#agregar la cadena "Radio" en la columna categoria si la columna "Nombre del Producto" tiene estrictamente la cadena radio como primera cadena
df.loc[df['Nombre del Producto'].str.contains('^radio', case=False), 'Categoria'] = 'Radio'

# %%
#ver valores con la palabra convertidor
df[df['Nombre del Producto'].str.contains('convertidor|tv stick|tv box', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 867   TV15112                      TV BOX MXQ-4K (1GB+8GB) Peiso       2.0
# 1470  TV10917                              TV BOX (2G+16G) TX100       1.0
# 1471  TV10918                               TV BOX T96D (2G+16G)       1.0
# 1529   TV7618       Xiaomi Mi Tv Stick 4k Ram 2gb 8gb Android Tv       1.0
# 1541  TV10919  CONVERTIDOR TV STICK 2GB 16GB ANDROID 10 SYSTE...       0.0
# 1548  CO11264  XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + AND...       0.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 867         38.92  107952.898402          277392.0     108000.0
# 1470        47.31   84942.754900          179566.0      85000.0
# 1471        45.17   87445.344300          193613.0      87500.0
# 1529        57.13   99430.867009          174064.0      99500.0
# 1541         0.00       0.000000               NaN          0.0
# ...

# %%
#añadir la cadena "Convertidor Smart" en la columna categoria si la columna "Nombre del Producto" contiene la cadena convertidor o tv stick o tv box
df.loc[df['Nombre del Producto'].str.contains('convertidor|tv stick|tv box', case=False), 'Categoria'] = 'Convertidor Smart'

# %%
#leer com df el archivo excel : Reporte de ventas por articulos MOD
df = pd.read_excel('Reporte de ventas por articulos MOD.xlsx')

# %%
#str columna 'Categoria' y 'Nombre del Producto'
df['Categoria'] = df['Categoria'].astype(str)
df['Nombre del Producto'] = df['Nombre del Producto'].astype(str)

# %%
df
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 0     R124132  VIDRIO GLASS SAMSUNG  A02S / A03 / A03 CORE / ...      90.0
# 1      PI3017                       Pilas Boton 3 V Philco 2032       70.0
# 2       D1014  CABLE USB ONLY MOD48 / V8 / 3,1A BLANCO Y NEGR...      55.0
# 3          C6  Pin Carga Sam J7 pro / J7 prime / J5 prime / J...      54.0
# 4       SE966            SERVICIO TECNICO REVISION Y PRESUPUESTO      54.0
# ...       ...                                                ...       ...
# 1550  RC76393  BATERIA SAM A14 / A52 / S20 FE / A52S 100% Ori...      -1.0
# 1551   PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
# 1552      NaN                                                nan       NaN
# 1553      NaN                                                nan       NaN
# 1554      NaN                                                nan    6294.0
#
#       Costo total      Ganancia  Ganancia prom. %   Venta total  \
# ...

# %%
#ver filas con valores en la columna categoria cn un
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    211
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# Camara wifi Ezviz interior inteligente - C6N 1080p               1
# EXTENSOR / REPETIDOR KANJI KJN-RP4200A                           1
# EXTENSOR DE RANGO Tp-Link Re200 Dual Band 2.4Ghz 5Ghz Ac750      1
# FILM MEMBRANA CONDUCTOR JOYSTICK PS4 JDM-040                     1
# Pendrive Kingston DataTraveler SE9 DTSE9H 32GB 2.0 plateado      1
# Name: count, Length: 201, dtype: int64

# %%
#ver valores con la cadena badeja sim en la columna "Nombre del Producto"
df[df['Nombre del Producto'].str.contains('bandeja sim', case=False)]
# Out:
#     Código                                Nombre del Producto  Cantidad  \
# 979   B130                         BANDEJA SIM S10 / S10 PLUS       1.0
# 980   B100  BANDEJA SIM SAM A10 / A10S / A20 / A30 / A50 /...       1.0
# 981   B131                                BANDEJA SIM SAM A31       1.0
# 982   B116                BANDEJA SIM SAM S8 / S8 PLUS SYLVER       1.0
#
#      Costo total   Ganancia  Ganancia prom. %  Venta total  \
# 979         0.34  5499.5886      1.617550e+11       5500.0
# 980         0.34  5099.5886      1.499900e+10       5100.0
# 981         0.34  5099.5886      1.499900e+10       5100.0
# 982         0.34  4999.5886      1.470490e+11       5000.0
#
#                                              Categoria
# 979                         BANDEJA SIM S10 / S10 PLUS
# 980  BANDEJA SIM SAM A10 / A10S / A20 / A30 / A50 /...
# 981                                BANDEJA SIM SAM A31
# 982                BANDEJA SIM SAM S8 / S8 PLUS SYLVER

# %%
#Agregar la cadena en la columna categoria la cadena "Badeja SIM" si la columna "Nombre del Producto" contiene la cadena "bandeja sim"
df.loc[df['Nombre del Producto'].str.contains('bandeja sim', case=False), 'Categoria'] = 'Badeja SIM'

# %%
#ver filas donde nombre del producto sea igual a categoria
df[df['Nombre del Producto'] == df['Categoria']]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 40      H8990               BOTELLA PLASTICA (con aguja) RL-054       25.0
# 48     AD7052      CONVERSOR HDMI A VGA CON CABLE AUDIO SM-C7819      21.0
# 52      R9519                         TACTIL SAM J2 PRIME SYLVER      20.0
# 126    PE2826  Pendrive Patriot 64gb Supersonico Rage Lite Us...      10.0
# 158   CA71103           CABEZAL PARA IPHONE 20W TIPO C MU7U2LL/A       8.0
# ...       ...                                                ...       ...
# 1535    TV598  Antena Tda 4k 5.0 Dbi Con Cable De 5 Mts Inter...       0.0
# 1541  TV10919  CONVERTIDOR TV STICK 2GB 16GB ANDROID 10 SYSTE...       0.0
# 1543    A7034  Conversor Hdmi A Rca Audio Y Video AV 1080p HD...       0.0
# 1548  CO11264  XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + AND...       0.0
# 1551   PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# ...

# %%
#ver valores que tengna estricamente  la cadena "hub" en la columa nombre del producto
df[df['Nombre del Producto'].str.contains('hub', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 153    AD2136         ADAPTADOR HUB USB CON 4 PUERTOS USB SX-36        8.0
# 395    AD2107              HUB 4 PUERTOS USB 1MTS DINAX DX-HUB1M       4.0
# 615    AD2137  ADAPTADOR HUB 3 EN 1 TIPO-C A HDMI+USB3.0+PD B...       2.0
# 616    AD2140  ADAPTADOR HUB 5 EN 1 TIPO-C A HDMI+USB3.0+PD+P...       2.0
# 617    AD2141  ADAPTADOR HUB 5 EN 1 TIPO-C A SD/TF+USB3.0+USB...       2.0
# 618    AD2142  ADAPTADOR HUB 6 EN 1 TIPO-C A HDMI+SD/TF+USB2....       2.0
# 619     SX-38  ADAPTADOR HUB IPHONE CON 3 PUERTOS USB Y 1 PUE...       2.0
# 735    KQ009H           Hub Usb 3.0 De 4 Puertos Aluminio Kq009H       2.0
# 1167    AD299                  HUB TIPO C SEISA BYL-2103T 5 IN 1       1.0
# 1168   KQ-009  Hub Adaptador Tipo C A Hdmi / Vga / Usb 3.0 / ...       1.0
# 1169   KQ008H                    Hub Usb 3.0 De 4 Puertos Kq008H       1.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "HUB" si la columna "Nombre del Producto" contiene la cadena "hub" y que no tenga las cadenas : adaptador
df.loc[df['Nombre del Producto'].str.contains('hub', case=False) & ~df['Nombre del Producto'].str.contains('adaptador', case=False), 'Categoria'] = 'HUB'

# %%
#ver valores con la cadena lente camara
df[df['Nombre del Producto'].str.contains('lente camara', case=False)]
# Out:
#      Código                      Nombre del Producto  Cantidad  Costo total  \
# 397    L111   LENTE CAMARA IPHONE 11 12 12 Mini X2 U       4.0         0.92
# 524    L114                    LENTE CAMARA IPHONE X       3.0         0.33
# 751    L141               LENTE CAMARA IPHONE 11 PRO       2.0         0.58
# 1204   L139  LENTE CAMARA IPHONE 6 6S 6S PLUS 6 PLUS       1.0         0.06
# 1205   L161               LENTE CAMARA MOTO G8 POWER       1.0         0.11
# 1206   L130         LENTE CAMARA SAM A10 / a20 / a30       1.0         0.11
# 1207   L119           LENTE CAMARA XIAOMI NOTE 8 PRO       1.0         0.23
#
#           Ganancia  Ganancia prom. %  Venta total  \
# 397   14198.888844      1.543380e+11      14200.0
# 524    6499.600700      1.969600e+10       6500.0
# 751    8799.303780      1.517140e+11       8800.0
# 1204   2399.927400      3.999900e+10       2400.0
# 1205   1999.866900      1.818080e+11       2000.0
# 1206   1999.866900      1.818080e+11       2000.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Lente Camara" si la columna "Nombre del Producto" contiene la cadena "lente camara"
df.loc[df['Nombre del Producto'].str.contains('lente camara', case=False), 'Categoria'] = 'Lente Camara'

# %%
#ver valores que tengan estrictamente como primera cadena, la cadena "celular" en la columan nombre del producto
df[df['Nombre del Producto'].str.contains('^celular', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 248   CE8153    CELULAR NOKIA 106 Dual SIM 4 MB RAM GRIS OSCURO       6.0
# 1094  CE8123      Celular Motorola Moto G13 64gb / 4gb RAM Gris       1.0
# 1095  CE8107  Celular Motorola Moto G32 128GB / 4GB Ram Plat...       1.0
# 1096  CE9190      Celular Samsung Galaxy A04 32GB/3GB RAM VERDE       1.0
# 1097  CE8130      Celular Samsung Galaxy A04 64GB/4GB RAM Negro       1.0
# 1098  CE8138     Celular Samsung Galaxy A14 128gb/4gb Ram Negro       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 248     104400.00  118676.000000            148.08     259000.0
# 1094        54.22   26734.389269          49328.30      26800.0
# 1095        65.07  359921.265300         774450.00     504000.0
# 1096        29.34  194964.501142         664522.00     195000.0
# 1097        62.90  294923.891000         468898.00     295000.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Celular" en las filas que tengan estrictamente como primera cadena, la cadena "celular" en la columan nombre del producto
df.loc[df['Nombre del Producto'].str.contains('^celular', case=False), 'Categoria'] = 'Celular'

# %%
#ver valores con la cadena pendrive o pre drive
df[df['Nombre del Producto'].str.contains('pendrive|pre drive|pen drive', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 126   PE2826  Pendrive Patriot 64gb Supersonico Rage Lite Us...      10.0
# 222   PE2822  PENDRIVE KINGSTON 3.2 dtx 128Gb Exodia Negro/A...       7.0
# 271   PE8820  Pen Drive KINGSTON 32GB USB 3.2 DTXM EXODIA M ...       6.0
# 272   PE8816               Pen Drive Sandisk Cruzer Blade 128gb       6.0
# 424   PE2825  Pen Drive HIKSEMI 64Gb M200S Rotary USB 3.0 (6...       4.0
# 425     P885   Pen Drive KINGSTON 32GB USB 3.2 DTX EXODIA NEGRO       4.0
# 834   PE2824              Pendrive Patriot 64gb Push + Usb 3.2        2.0
# 1551  PE8818  Pendrive Kingston DataTraveler SE9 DTSE9H 32GB...      -2.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 126         65.30  135420.985500          207404.0  135499.9985
# 222         66.05  136340.080300          206440.0  136420.0008
# 271         41.46   73349.833400          176938.0   73400.0000
# ...

# %%
#añadir la cadena "Pendrive" en la columna categoria si la columna "Nombre del Producto" contiene la cadena pendrive o pre drive o pen drive
df.loc[df['Nombre del Producto'].str.contains('pendrive|pre drive|pen drive', case=False), 'Categoria'] = 'Pendrive'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    211
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# SERV TEC TACTIL Y LCD                                            1
# SERV TEC PIN                                                     1
# Radio Retro Am Fm Con Linterna Y Bluetooth Seisa YX-123UBT       1
# ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI 300MBPS           1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 174, dtype: int64

# %%
#agrergar la cadena "Herramienta" en la columna categoria si la columna "Nombre del Producto" contiene las siguientes cadenas: hoja de puntos, base separadora, botella plastica
df.loc[df['Nombre del Producto'].str.contains('hoja de puntos|base separadora|botella plastica', case=False), 'Categoria'] = 'Herramienta'

# %%
#VER VALORES CON LA CADENA CAMARA
df[df['Nombre del Producto'].str.contains('camara web', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 379   CA1154979  Camara Web Naxido 1080p W9n Full Hd 30fps Con ...       4.0
# 700        C007           Camara Web 1080p USB Con Microfono C007        2.0
# 1087     CA7430        Camara Web Webcam Xiaomi W88 FULL HD(1080P)       1.0
# 1088     CA7436            Camara web GENIUS Facecam 1000x 720p hd       1.0
#
#       Costo total    Ganancia  Ganancia prom. %  Venta total  \
# 379         38.72  77953.1488          201346.0      78000.0
# 700         21.00  36776.7950          175138.0      36800.0
# 1087        23.23  57971.8917          249577.0      58000.0
# 1088        15.70  27981.0030          178244.0      28000.0
#
#                                         Categoria
# 379                                          Tapa
# 700      Camara Web 1080p USB Con Microfono C007
# 1087  Camara Web Webcam Xiaomi W88 FULL HD(1080P)
# 1088      Camara web GENIUS Facecam 1000x 720p hd

# %%
#Agregar la cadena en la columna categoria la cadena "Camara Web" si la columna "Nombre del Producto" tiene estrictamente la cadena camara web
df.loc[df['Nombre del Producto'].str.contains('camara web', case=False), 'Categoria'] = 'Camara Web'

# %%
#ver valores con la cadena camara
df[df['Nombre del Producto'].str.contains('camara', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 111    CA712086  TRANSFORMADOR FUENTE TIRA DE LED CCTV CAMARAS ...      11.0
# 341      SO5539  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,02...       5.0
# 342      SO5540  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,40...       5.0
# 379   CA1154979  Camara Web Naxido 1080p W9n Full Hd 30fps Con ...       4.0
# 397        L111             LENTE CAMARA IPHONE 11 12 12 Mini X2 U       4.0
# 483      CA1159             CAMARA SMART IP 720P DINAX DX-CAMSMAIP       3.0
# 488     CA11437   Camara De Seguridad Ip 3Mp Seisa IPC-S036 Blanco       3.0
# 513      VI6043  Film Vidrio Templado CAMARA FULL Para Iphone 1...       3.0
# 524        L114                              LENTE CAMARA IPHONE X       3.0
# 698     CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 699     CA11438  Camara De Seguridad IPC-ZAS05 DOBLE LENTE 360 ...       2.0
# ...

# %%
#ver valores con la cadena tactil
df[df['Nombre del Producto'].str.contains('tactil', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 52        R9519                         TACTIL SAM J2 PRIME SYLVER      20.0
# 185      RVG188       VIDRIO GLASS MOTO E6 PLUS NEGRO +OCA +TACTIL       8.0
# 229    RC124158              VIDRIO GLASS SAMSUNG A01 TACTIL +OCA        7.0
# 349      RVG187  VIDRIO GLASS MOTOROLA E6 PLAY NEGRO + OCA +TACTIL       5.0
# 450      RVG185    VIDRIO GLASS MOTO E5 PLAY GO NEGRO +OCA +TACTIL       4.0
# 585        S964                              SERV TEC TACTIL Y LCD       3.0
# 606      RVG163       VIDRIO GLASS MOTO G5S PLUS NEGRO TACTIL +OCA       3.0
# 631      AU3281       AURICULARES BT NOGA NG-BTWINS 26 TACTIL ROJO       2.0
# 862      RVG192                           TACTIL  LG K40s NEGRO +O       2.0
# 888     RC93229  VIDRIO GLASS  XIAOMI MI A2 LITE NEGRO +OCA +TA...       2.0
# 895     RC93211       VIDRIO GLASS MOTO E4 PLUS NEGRO +OCA +TACTIL       2.0
# ...

# %%
#ver valores con la cadena touch
df[df['Nombre del Producto'].str.contains('touch', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 599     RT1001  Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FP...       3.0
# 885    R101118  Touch Mas Simple 8 pulgadas / L201190610 06.38...       2.0
# 908     RT1066                4B1 Touch Philco TP7A1I / PB70A2229       1.0
# 1120   LU19104  ESPEJO RECTANGULAR TOUCH CON LUZ LED DINAX / D...       1.0
# 1211  VIR-4556  Lampara De Escritorio Usb Oficina Led Velador ...       1.0
# 1495    RT1002  Touch 3G / 0101-T 2014.02, c184104a1-fpc738dr,...       1.0
# 1496    RT1137   Touch Alcatel 8067 / TCL LT7 M / wj1901-fpc v5.0       1.0
# 1497    RT1083  Touch C145254K1-DRFPC391T-V2.0 / MF-817-101F-3...       1.0
# 1498    RT1100  Touch Samsung Tab 3 SM-T111 (solo BLANCO) RANU...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 599         11.31  18487.511986      1.634720e+05      18500.0
# 885         29.50  60967.392409      2.066800e+05      61000.0
# ...

# %%
#ver valores que tengan estrictamente la cadena tactil como primera cadena en su valor
df[df['Nombre del Producto'].str.contains('^tactil', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 52     R9519                         TACTIL SAM J2 PRIME SYLVER      20.0
# 862   RVG192                           TACTIL  LG K40s NEGRO +O       2.0
# 1456   RT305                           TACTIL LG K4 K120 GRANDE       1.0
# 1457   RT310                          TACTIL SAM J2 PRIME BLACK       1.0
# 1458  RT1003  TACTIL TITAN JZ-1003-FPCV1 / ONTOP ATC7015 FPC...       1.0
# 1477  RT1104  Tactil Samsung Galaxy Tab 3 Lite T113NU CAMARA...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 52          16.00  76980.651050          481150.0      77000.0
# 862          8.78  10889.364155          124046.0      10900.0
# 1456         0.57   1999.309361          350777.0       2000.0
# 1457         0.80   2499.033105          312400.0       2500.0
# 1458         4.39   7495.143550          170743.0       7500.0
# 1477        12.56  16686.124429          132862.0      16700.0
#
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Tactil" si en la columna "Nombre del Producto" tiene estrictamente la cadena "tactil" como primera cadena de su valor
df.loc[df['Nombre del Producto'].str.contains('^tactil', case=False), 'Categoria'] = 'Tactil'

# %%
#ver valores unicos en la columna categoriia
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    214
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# SERV TEC PIN                                                     1
# Radio Retro Am Fm Con Linterna Y Bluetooth Seisa YX-123UBT       1
# ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI 300MBPS           1
# RADIO RETRO AM FM CON LINTERNA / BLUETOOTH SEISA YX-119UBT       1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 164, dtype: int64

# %%
#ver valores con la acadena tablet
df[df['Nombre del Producto'].str.contains('tablet', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 15         C4                      Pin Carga Tablet Varios 8520       36.0
# 141     AC169  Lapiz Optico Doble Punta Para Smartphone Table...       9.0
# 314      H890   Kit Destornilladores Yaxun YX6028 Tablet Celular       5.0
# 335       C78  Pin Carga Tipo C Tablet Anses Mas Simple / Gad...       5.0
# 398     AC171  Lapiz optico Pen Stylus JAZAK WK24 / Compatibl...       4.0
# 439    SO5554  SOPORTE PARA CELULAR / TABLET - SA18 NEGRO GM-...       4.0
# 520   HE89342   Kit Destornilladores Yaxun YX6310 Tablet Celular       3.0
# 595    SO5562  Soporte Regulable Giratorio 360º Para Tablet Y...       3.0
# 638    AD7086  Adaptador Otg Micro Usb A Usb Hembra Tablet Ce...       2.0
# 857    SO5555  SOPORTE DE MESA PLEGABLE / NOTEBOOK 13 / TABLE...       2.0
# 1230     M785  MICROFONO DE PIE SF-950  FICHA 3.5mm PC-CELULA...       1.0
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Tablet" si en la columna "Nombre del Producto" tiene estrictamente la cadena tablet como primera cadena
df.loc[df['Nombre del Producto'].str.contains('^tablet', case=False), 'Categoria'] = 'Tablet'

# %%
#ver valores con la cadena lapiz en su nombre
df[df['Nombre del Producto'].str.contains('lapiz', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 141    AC169  Lapiz Optico Doble Punta Para Smartphone Table...       9.0
# 211   AC7258                             Lapiz optico R06 METAL       7.0
# 398    AC171  Lapiz optico Pen Stylus JAZAK WK24 / Compatibl...       4.0
# 504  HE89227  Estacion De Soldado Lapiz Cautin Con Regulador...       3.0
# 526    AC172         Lapiz optico TARGUS MAGNETICO 5" AMM168GLX       3.0
#
#      Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 141         7.20   16192.044000          224900.0      16200.0
# 211        58.45  100735.409218          172355.0     100800.0
# 398        58.40   95535.468000          163599.0      95600.0
# 504        71.58  141220.909247          197302.0     141300.0
# 526        17.70   28680.441500          162047.0      28700.0
#
#                                              Categoria
# 141                                        Herramienta
# ...

# %%
#agregar la cadena "Lapiz optico" en la columna categoria si la columna "Nombre del Producto" contiene estrictamente la cadena lapiz como primera cadena de su valor
df.loc[df['Nombre del Producto'].str.contains('^lapiz', case=False), 'Categoria'] = 'Lapiz Optico'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# SEÑA POR ARREGLO                                                 1
# SERV TEC TACTIL Y LCD                                            1
# SERV TEC PIN                                                     1
# Radio Retro Am Fm Con Linterna Y Bluetooth Seisa YX-123UBT       1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 161, dtype: int64

# %%
#ver valores con la cadena conversor
df[df['Nombre del Producto'].str.contains('conversor', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 48    AD7052      CONVERSOR HDMI A VGA CON CABLE AUDIO SM-C7819      21.0
# 201   AD2135     CONVERSOR DE AUDIO OPTICO A RCA AUDIO SM-C7812       7.0
# 252   AD7051  Conversor Display Port A a HDMI Full HD 1080p ...       6.0
# 1070   A7026  CONVERSOR VGA A HDMI CON AUDIO Y USB (CABLE) 1244       1.0
# 1103  AD7078  Conversor Gamer Para Teclado Y Mouse A Celular...       1.0
# 1104  AD7091  Conversor Rca Audio Y Video AV A Hdmi 1080p AV...       1.0
# 1105  AD7072    Conversor de VGA + Audio a HDMI Activo VGA2HDMI       1.0
# 1320   A7023  NISUTA Conversor Adaptador De Usb A 2 Ps2 NS-C...       1.0
# 1543   A7034  Conversor Hdmi A Rca Audio Y Video AV 1080p HD...       0.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 48          71.40  156313.606000          218948.0  156400.0000
# 201         41.22   76850.123800          188401.0   77700.0000
# ...

# %%
#Agregar la cadena en la columna categoria la cadena "Conversor" si la columna "Nombre del Producto" contiene la cadena conversor
df.loc[df['Nombre del Producto'].str.contains('conversor', case=False), 'Categoria'] = 'Conversor'

# %%
#ver valores con la cadena boton
df[df['Nombre del Producto'].str.contains('boton', case=False)]
# Out:
#       Código           Nombre del Producto  Cantidad  Costo total  \
# 1     PI3017  Pilas Boton 3 V Philco 2032       70.0        32.20
# 1022   RB101           BOTON HOME IPHONE 7       1.0         0.09
#
#           Ganancia  Ganancia prom. %  Venta total            Categoria
# 1     73911.053000      2.295580e+05    73950.015                 Pila
# 1022  12999.889498      1.444430e+12    13000.000  BOTON HOME IPHONE 7

# %%
#añadir la cadena "Boton" en la columna categoria si la columna "Nombre del Producto" contiene estrictamente como primera cadena, la cadena "boton"
df.loc[df['Nombre del Producto'].str.contains('^boton', case=False), 'Categoria'] = 'Boton'

# %%
#ver valores con la cadena flex
df[df['Nombre del Producto'].str.contains('flex', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 308      H9060                           DOCK FLEX TEST (TIPO C)        5.0
# 390       F393                   FLEX INTERCONEXION SAM A50 NO. 2       4.0
# 436     SE5312                   SERVICIO TECNICO REPARACION FLEX       4.0
# 507       FC03                      FLEX DE CARGA IPHONE 6S WHITE       3.0
# 508       FC42            FLEX DE CARGA IPHONE 8 PLUS WHITE/BLACK       3.0
# 509       F404                     FLEX INTERCONEXION SAMSUNG A52       3.0
# 628   AU127145  AURICULAR JBL WAVE FLEX TRULY WIRELESS NEGRO (...       2.0
# 706      H9058                             DOCK FLEX TEST (Micro)       2.0
# 724       F403                   FLEX INTERCONEXION MOTO G9 POWER       2.0
# 725       F401  FLEX INTERCONEXION SAM A22 4G - A225 / A32 - A325       2.0
# 726       F400                        FLEX INTERCONEXION SAM A30S       2.0
# ...

# %%
#ver valores con la cadena reloj
df[df['Nombre del Producto'].str.contains('reloj', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 206      C7164            Cargador Reloj Xiaomi Mi Band 5 / 6 / 7       7.0
# 213    RE11742                MALLA REPUESTO PARA RELOJ 22mm AZUL       7.0
# 704     RE7756                       Cargador USB Reloj SAM FIT 2       2.0
# 755     RE7730             MALLA REPUESTO PARA RELOJ 20mm COLORES       2.0
# 756    REL2013  MALLA REPUESTO PARA RELOJ MI BAND 5 / BAND 6 C...       2.0
# 849     RE9472           RELOJ INTELIGENTE IMILAB W02 1,85" Negro       2.0
# 1215   RE11745                MALLA REPUESTO PARA RELOJ 20mm GRIS       1.0
# 1412    RE9483  RELOJ DESPERTADOR C/CALENDARIO/TEMPERATURA DS-...       1.0
# 1413    RE9485          RELOJ DESPERTADOR CARGA INALAMBRICA AY-21       1.0
# 1414    RE7753       RELOJ INTELIGENTE SMARTWATCH W17 PRO - BLACK       1.0
# 1415  RE775416           RELOJ KIESLECT SMARTWATCH CALLING KR PRO       1.0
# ...

# %%
#reemplazar en la columna nombre del producto ,si una cadena es igual a smartwach , reemplazar esa cadena por smarwatch
df['Nombre del Producto'] = df['Nombre del Producto'].str.replace('smartwach', 'Smartwatch', case=False)

# %%
#ver valores que tengan estrictamente alguna de las siguientes cadenas: reloj inteligente, reloj smartwatch
df[df['Nombre del Producto'].str.contains('reloj inteligente|reloj smartwatch', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 849    RE9472           RELOJ INTELIGENTE IMILAB W02 1,85" Negro       2.0
# 1414   RE7753       RELOJ INTELIGENTE SMARTWATCH W17 PRO - BLACK       1.0
# 1422   RE7745  Reloj Inteligente Smartwatch XIAOMI MI KIESLEC...       1.0
# 1423   RE9468  Reloj Smartwatch BT Netmak / Pulsaciones km fi...       1.0
# 1424  RE94102  Reloj Smartwatch BT Netmak / Pulsaciones km fi...       1.0
# 1435  ULTRA94  SMARTWATCH RELOJ INTELIGENTE ULTRA 94 NOTIFICA...       1.0
# 1549    R7719  Xiaomi Mi Band 6 Smartwatch Reloj Inteligente ...       0.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 849         98.70  184890.938014          187337.0     185000.0
# 1414        22.60   44975.023973          199015.0      45000.0
# 1422        32.65   55763.923516          170804.0      55800.0
# 1423        10.55   18488.342250          175255.0      18500.0
# ...

# %%
#añadir la cadena "Smartwatch" en la columna categoria si la columna "Nombre del Producto" contiene estrictamente alguna de las siguientes cadenas: reloj inteligente, reloj smartwatch
df.loc[df['Nombre del Producto'].str.contains('reloj inteligente|reloj smartwatch', case=False), 'Categoria'] = 'Smartwatch'

# %%
#ver valores unicos en la columna cateogria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# SEÑA POR ARREGLO                                                 1
# SERV TEC TACTIL Y LCD                                            1
# SERV TEC PIN                                                     1
# Radio Retro Am Fm Con Linterna Y Bluetooth Seisa YX-123UBT       1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 151, dtype: int64

# %%
#Cambiar a este producto en su columna categoria por la cadena Auricular
df.loc[df['Código'] == 'AU3292', 'Categoria'] = 'Auricular'

# %%
#ver valores con la cadena radio
df[df['Nombre del Producto'].str.contains('radio', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 331   PA131159  PARLANTE PORTATIL RADIO Y LECTOR TARJETA YX-07...       5.0
# 580    PA64122  RADIO RETRO AM FM CON LINTERNA / BLUETOOTH SEI...       3.0
# 583    PA64124  Radio Retro Am Fm Con Linterna Y Bluetooth Sei...       3.0
# 844   PA131151  RADIO PORTATIL BLUETOOTH VINTAGE RETRO NEGRO S...       2.0
# 960    AU60229  Auricular Bluetooth NIA Q8-851S Manos Libres E...       1.0
# 1023  PA131144  Barra Sonido Tv o Pc Bluetooth / Sd / Radio / ...       1.0
# 1329    PA6486   PARLANTE MULTIMEDIA RADIO 6,5" NGL-400BT TWS/USB       1.0
# 1381  KTS-1687  Parlante Bt Radio iKaraoke box con microfono I...       1.0
# 1409  PA131135       RADIO PORTATIL POCKET DINAX AM/FM DX-RADIOP1       1.0
# 1419  PA131145  Radio Bluetooth Am / Fm Con Linterna Y Panel S...       1.0
# 1420  PA131158      Radio Retro Am Fm Y Bluetooth Seisa YX-303UBT       1.0
# ...

# %%
#añadir la cadena "Radio" en la columna categoria si la columna "Nombre del Producto" contiene estrictamente la cadena radio como primera cadena
df.loc[df['Nombre del Producto'].str.contains('^radio', case=False), 'Categoria'] = 'Radio'

# %%
#ver valores con la cadena barra sonido
df[df['Nombre del Producto'].str.contains('barra sonido', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 1023  PA131144  Barra Sonido Tv o Pc Bluetooth / Sd / Radio / ...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 1023        53.18  96935.653139          182299.0      97000.0
#
#                                               Categoria
# 1023  Barra Sonido Tv o Pc Bluetooth / Sd / Radio / ...

# %%
#cambiar la categoria de ese producto por la cadena parlante
df.loc[df['Nombre del Producto'].str.contains('barra sonido', case=False), 'Categoria'] = 'Parlante'

# %%
#ver valores con la cadena estabilizador
df[df['Nombre del Producto'].str.contains('estabilizador', case=False)]
# Out:
#      Código                                Nombre del Producto  Cantidad  \
# 385  SO5542       ESTABILIZADOR KIT CON LUZ Y MICROFONO AY-49U       4.0
# 499  EL1315  ESTABILIZADOR DE TENSION ATOMLUX R500@ 220V 6 ...       3.0
# 503  EL1318  Estabilizador Surelectric Future 6 Bocas 220v-...       3.0
#
#      Costo total     Ganancia  Ganancia prom. %  Venta total  \
# 385         66.0  111420.1400          168839.0  111500.0000
# 499        111.0  170077.3481          166004.0  184375.0031
# 503         51.0   97943.6450          192057.0   98000.0000
#
#                                              Categoria
# 385       ESTABILIZADOR KIT CON LUZ Y MICROFONO AY-49U
# 499  ESTABILIZADOR DE TENSION ATOMLUX R500@ 220V 6 ...
# 503  Estabilizador Surelectric Future 6 Bocas 220v-...

# %%
#agregar la cadena "Estabilizadores" en la columna categoria si la columna "Nombre del Producto" contiene la cadena estabilizador
df.loc[df['Nombre del Producto'].str.contains('estabilizador', case=False), 'Categoria'] = 'Estabilizador'

# %%
#ver valores con la cadena wifi
df[df['Nombre del Producto'].str.contains('wifi', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 270     CO953       PLACA USB/WIFI 150M CON ANTENA 5DBI DNW150U2       6.0
# 434    CO8138  Receptor USB NANO Wireless WIFI AC600 Dual ban...       4.0
# 467     C8114  Antena Externa Adaptador Usb Wifi Placa Red La...       3.0
# 533     C8118  Mini Adaptador USB Wifi tp-link TL-WN823N 300M...       3.0
# 569     CO952  PLACA USB/WIFI 150M CON ANTENA DN-W150U3 or 13...       3.0
# 698   CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 699   CA11438  Camara De Seguridad IPC-ZAS05 DOBLE LENTE 360 ...       2.0
# 701    CA7431  Camara wifi Ezviz interior inteligente - C6N 1...       2.0
# 848     CO957  RECEPTOR WIFI DINAX DOBLE BANDA 1300MBPS / DXR...       2.0
# 851     CO946  ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...       2.0
# 951   NG-Uw06  Adaptador Inalambrico Wifi Usb Red Noga NG-Uw0...       1.0
# ...

# %%
#ver valores con la cadena repetidor y extensor
df[df['Nombre del Producto'].str.contains('repetidor|extensor', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 203    CA74155  Cable Extensor Usb 2.0 Macho A Macho Con Filtr...       7.0
# 387      CO949   EXTENSOR / REPETIDOR KANJI KJN-RP4200B 4 ANTENAS       4.0
# 714      CO950             EXTENSOR / REPETIDOR KANJI KJN-RP4200A       2.0
# 715   EXTRE200  EXTENSOR DE RANGO Tp-Link Re200 Dual Band 2.4G...       2.0
# 1126    AD2110  EXTENSOR DE HDMI POR UTP RED ETHERNET 30M GM57...       1.0
# 1127   CO95761  EXTENSOR DE RANGO De Wifi 300mbps 2.4ghz REP-R...       1.0
# 1417     CO958        REPETIDOR WIFI 2 ANTENAS DINAX / REPRP4200C       1.0
#
#       Costo total       Ganancia  Ganancia prom. %   Venta total  \
# 203         23.92   48371.073702          202241.0   48400.00320
# 387         52.72  101941.717753          193375.0  101999.99515
# 714         20.34   33977.521575          167058.0   34000.00000
# 715         52.20   90742.319000          173846.0   90800.00000
# ...

# %%
 #agregar la cadena "Extensor Wifi" en la columna categoria si la columna "Nombre del Producto" contiene la cadena repetidor o extensor y no contiene las siguientes cadenas: cable, hdmi
df.loc[df['Nombre del Producto'].str.contains('repetidor|extensor', case=False) & ~df['Nombre del Producto'].str.contains('cable|hdmi', case=False), 'Categoria'] = 'Extensor Wifi'

# %%
#agregar la cadena Adaptador en la columna categoria si la columna "Nombre del Producto" contiene la cadena extensor de hdmi
df.loc[df['Nombre del Producto'].str.contains('extensor de hdmi', case=False), 'Categoria'] = 'Adaptador'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                                                          213
# Modulo                                                                                               125
# Bateria                                                                                              115
# Auricular                                                                                            103
# Vidrio Glass                                                                                          96
#                                                                                                     ...
# Transmisor Inalambrico Bluetooth Auto Manos Libres CarF7 TIPO C                                        1
# Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FPC-TP0702015 / FPC-TP070226 / ZJ-70065F / WJ615-V1.0      1
# SPLITTER HDMI 1 A 2 4K / ADP-48006                                                                     1
# ...

# %%
#ver valores con la cadena receptor
df[df['Nombre del Producto'].str.contains('receptor ', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 182    CO947                      Receptor BT Bluetooth USB 5,0       8.0
# 433   AD2131  RECEPTOR DE AUDIO BLUETOOTH BT350 BT-350 or 14...       4.0
# 434   CO8138  Receptor USB NANO Wireless WIFI AC600 Dual ban...       4.0
# 846    CO948           RECEPTOR BLUETOOTH DOBLE SALIDA BLS-BT02       2.0
# 847   AD2105             RECEPTOR BLUETOOTH DX-REPBLUE810 DINAX       2.0
# 848    CO957  RECEPTOR WIFI DINAX DOBLE BANDA 1300MBPS / DXR...       2.0
# 1410   CO954          RECEPTOR 2.4G WIFI+BLUETOOTH 4.2 BT-165         1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 182         17.44   51780.740708          296918.0   51800.0000
# 433          8.00   16490.320000          206150.0   16500.0000
# 434         72.00  129820.440000          180317.0  129900.0000
# 846          6.94   12992.340685          187220.0   13000.0000
# ...

# %%
#agregar la cadena 'Receptor' en la columna categoria si la columna 'Nombre del Producto' contiene la cadena receptor
df.loc[df['Nombre del Producto'].str.contains('receptor ', case=False), 'Categoria'] = 'Receptor'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                                                          213
# Modulo                                                                                               125
# Bateria                                                                                              115
# Auricular                                                                                            103
# Vidrio Glass                                                                                          96
#                                                                                                     ...
# Analogico Nintendo Switch Joy-Con Joystick Repuesto Original                                           1
# Transmisor Inalambrico Bluetooth Auto Manos Libres CarF7 TIPO C                                        1
# Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FPC-TP0702015 / FPC-TP070226 / ZJ-70065F / WJ615-V1.0      1
# ...

# %%
#ver valores con la cadena reloj despertador
df[df['Nombre del Producto'].str.contains('reloj despertador', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 1412  RE9483  RELOJ DESPERTADOR C/CALENDARIO/TEMPERATURA DS-...       1.0
# 1413  RE9485          RELOJ DESPERTADOR CARGA INALAMBRICA AY-21       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 1412         9.34  17988.695616          192619.0      18000.0
# 1413        15.63  28981.083390          185441.0      29000.0
#
#                                               Categoria
# 1412  RELOJ DESPERTADOR C/CALENDARIO/TEMPERATURA DS-...
# 1413          RELOJ DESPERTADOR CARGA INALAMBRICA AY-21

# %%
#agregar la cadena "Reloj Despertador" en la columna categoria si la columna "Nombre del Producto" contiene la cadena reloj despertador
df.loc[df['Nombre del Producto'].str.contains('reloj despertador', case=False), 'Categoria'] = 'Reloj Despertador'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                                                          213
# Modulo                                                                                               125
# Bateria                                                                                              115
# Auricular                                                                                            103
# Vidrio Glass                                                                                          96
#                                                                                                     ...
# Analogico Nintendo Switch Joy-Con Joystick Repuesto Original                                           1
# Transmisor Inalambrico Bluetooth Auto Manos Libres CarF7 TIPO C                                        1
# Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FPC-TP0702015 / FPC-TP070226 / ZJ-70065F / WJ615-V1.0      1
# ...

# %%
#ver valores con la cadena camara
df[df['Nombre del Producto'].str.contains('camara', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 111    CA712086  TRANSFORMADOR FUENTE TIRA DE LED CCTV CAMARAS ...      11.0
# 341      SO5539  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,02...       5.0
# 342      SO5540  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,40...       5.0
# 379   CA1154979  Camara Web Naxido 1080p W9n Full Hd 30fps Con ...       4.0
# 397        L111             LENTE CAMARA IPHONE 11 12 12 Mini X2 U       4.0
# 483      CA1159             CAMARA SMART IP 720P DINAX DX-CAMSMAIP       3.0
# 488     CA11437   Camara De Seguridad Ip 3Mp Seisa IPC-S036 Blanco       3.0
# 513      VI6043  Film Vidrio Templado CAMARA FULL Para Iphone 1...       3.0
# 524        L114                              LENTE CAMARA IPHONE X       3.0
# 698     CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 699     CA11438  Camara De Seguridad IPC-ZAS05 DOBLE LENTE 360 ...       2.0
# ...

# %%
#ver valores con las siguientes dos cadenas cadena y exterior
df[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('exterior', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 698   CA11447  Camara De Seguridad Exterior Imou Bullet 2c 10...       2.0
# 1044  CA11436  CAMARA EXTERIOR IP WIFI IMOU Cruiser Se+ 4mp F...       1.0
# 1045   CA7435     CAMARA IP CLOUD TP-LINK TAPO C310 3MP EXTERIOR       1.0
# 1083  CA11445  Camara De Seguridad Ezviz Domo Color Full H8C ...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 698         62.00  119924.980000          193448.0     120000.0
# 1044        65.99  118920.155194          180230.0     119000.0
# 1045        42.69   79948.340183          187298.0      80000.0
# 1083        46.00   89944.340000          195552.0      90000.0
#
#                                               Categoria
# 698                                 Camara de Seguridad
# 1044  CAMARA EXTERIOR IP WIFI IMOU Cruiser Se+ 4mp F...
# 1045     CAMARA IP CLOUD TP-LINK TAPO C310 3MP EXTERIOR
# ...

# %%
#agregar la cadena "Camara de Seguridad" en la columna categoria si la columna "Nombre del Producto" contiene las cadenas camara y exterior
df.loc[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('exterior', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
#ver valores que tengan estrictamente las dos cadenas siguientes : camara y wifi. Ademas en su categoria no tenga la cadena Camara de Seguridad
df[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('wifi', case=False) & ~df['Categoria'].str.contains('Camara de Seguridad', case=False)]
#a esos valores cambiar su categoria a Camara de Seguridad
df.loc[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('wifi', case=False) & ~df['Categoria'].str.contains('Camara de Seguridad', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
df[df['Nombre del Producto'].str.contains('camara', case=False) & df['Nombre del Producto'].str.contains('wifi', case=False) & ~df['Categoria'].str.contains('Camara de Seguridad', case=False)]
# Out:
# Empty DataFrame
# Columns: [Código, Nombre del Producto, Cantidad, Costo total, Ganancia, Ganancia prom. %, Venta total, Categoria]
# Index: []

# %%
#ver valores con la cadena camara smart
df[df['Nombre del Producto'].str.contains('camara smart', case=False)]
# Out:
#      Código                     Nombre del Producto  Cantidad  Costo total  \
# 483  CA1159  CAMARA SMART IP 720P DINAX DX-CAMSMAIP       3.0       102.78
#
#          Ganancia  Ganancia prom. %  Venta total  \
# 483  113875.62899          110817.0     114000.0
#
#                                   Categoria
# 483  CAMARA SMART IP 720P DINAX DX-CAMSMAIP

# %%
# a ese producto cambiarle la categoria a Camara de Seguridad
df.loc[df['Nombre del Producto'].str.contains('camara smart', case=False), 'Categoria'] = 'Camara de Seguridad'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                                                          213
# Modulo                                                                                               125
# Bateria                                                                                              115
# Auricular                                                                                            103
# Vidrio Glass                                                                                          96
#                                                                                                     ...
# Analogico Nintendo Switch Joy-Con Joystick Repuesto Original                                           1
# Transmisor Inalambrico Bluetooth Auto Manos Libres CarF7 TIPO C                                        1
# Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FPC-TP0702015 / FPC-TP070226 / ZJ-70065F / WJ615-V1.0      1
# ...

# %%
#ver valores con la cadena router
df[df['Nombre del Producto'].str.contains('router', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 391   CA6172  FUENTE UNIVERSAL 9V 1,5A DOBLE FICHA  ROUTER /...       4.0
# 582   CO8132  ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI...       3.0
# 851    CO946  ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...       2.0
# 1418  CO8130         ROUTER TP-LINK ARCHER C50 AC1200 4 ANTENAS       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 391          8.80   25989.352000          295355.0   26000.0000
# 582         78.73  163413.009771          207572.0  163500.0096
# 851         22.60   58972.650685          260962.0   59000.0000
# 1418        29.00   64967.955000          224038.0   65000.0000
#
#                                               Categoria
# 391                                         Herramienta
# 582   ROUTER TP-LINK TL-WR850N WISP 2 ANTENAS 2.5DBI...
# 851   ROUTER DINAX WIFI 4 ANTENAS IEEE 802.11N DX-7R...
# ...

# %%
#agregar la cadena "Router" en la columna categoria si la columna "Nombre del Producto" contiene la cadena router y no tiene la cadena fuente
df.loc[df['Nombre del Producto'].str.contains('router', case=False) & ~df['Nombre del Producto'].str.contains('fuente', case=False), 'Categoria'] = 'Router'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                                                          213
# Modulo                                                                                               125
# Bateria                                                                                              115
# Auricular                                                                                            103
# Vidrio Glass                                                                                          96
#                                                                                                     ...
# Analogico Nintendo Switch Joy-Con Joystick Repuesto Original                                           1
# Transmisor Inalambrico Bluetooth Auto Manos Libres CarF7 TIPO C                                        1
# Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FPC-TP0702015 / FPC-TP070226 / ZJ-70065F / WJ615-V1.0      1
# ...

# %%
#ver valores con la cadena vidrio templado y film glass
df[df['Nombre del Producto'].str.contains('vidrio templado|film glass', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 45      VT111  FILM GLASS COMUN SAM A02 / A04 - A04E - A04s /...      24.0
# 50    VI11459               FILM GLASS 9D MOTO E7 PLUS / G9 PLAY      20.0
# 120   VI13687  FILM GLASS COMUN SAM A11 / S20 FE / MOTO G13 /...      10.0
# 207   VI11462                        FILM GLASS 9D SAM A21 / A71       7.0
# 253     VT104    FILM GLASS 9D SAM A20 / A30 / A30S / A50 / A50S       6.0
# 310   VI11460                             FILM GLASS 9D MOTO G20       5.0
# 389   VI11463                              FILM GLASS 9D SAM A71       4.0
# 505     VT112                           FILM GLASS COMUN SAM A14       3.0
# 506     VT113  FILM GLASS COMUN SAM A20 / A30 / A30S / A50 / ...       3.0
# 513    VI6043  Film Vidrio Templado CAMARA FULL Para Iphone 1...       3.0
# 717   VI11458                        FILM GLASS 9D MOTO G9 POWER       2.0
# ...

# %%
#agregar la cadena "Vidrio templado" en la columna categoria si la columna "Nombre del Producto" contiene la cadena vidrio templado o film glass
df.loc[df['Nombre del Producto'].str.contains('vidrio templado|film glass', case=False), 'Categoria'] = 'Vidrio Templado'

# %%
#ver valores con la cadena smart wach
df[df['Nombre del Producto'].str.contains('smart wach|smartwatch', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 1414    RE7753       RELOJ INTELIGENTE SMARTWATCH W17 PRO - BLACK       1.0
# 1415  RE775416           RELOJ KIESLECT SMARTWATCH CALLING KR PRO       1.0
# 1416    RE9470       RELOJ KIESLECT SMARTWATCH CALLING KS (negro)       1.0
# 1422    RE7745  Reloj Inteligente Smartwatch XIAOMI MI KIESLEC...       1.0
# 1423    RE9468  Reloj Smartwatch BT Netmak / Pulsaciones km fi...       1.0
# 1424   RE94102  Reloj Smartwatch BT Netmak / Pulsaciones km fi...       1.0
# 1430    RE9494                Smartwatch AMAZFIT GTR MINI - BLACK       1.0
# 1431    RE9465  SMARTWATCH AMAZFIT GTS 4 MINI - BLACK Pantalla...       1.0
# 1432    RE9496                     SMARTWATCH KIESLECT KR - BLACK       1.0
# 1433   RE94100                            SMARTWATCH P8 GT - GOLD       1.0
# 1434    RE9490                      SMARTWATCH QCY GTS S2 - BLACK       1.0
# ...

# %%
#agregar la cadena "Smartwatch" en la columna categoria si la columna "Nombre del Producto" contiene la cadena smart wach o smartwatch
df.loc[df['Nombre del Producto'].str.contains('smart wach|smartwatch', case=False), 'Categoria'] = 'Smartwatch'

# %%
#ver valores con la cadena touch y tactil
df[df['Nombre del Producto'].str.contains('touch|tactil', case=False)]
# Out:
#          Código                                Nombre del Producto  Cantidad  \
# 52        R9519                         TACTIL SAM J2 PRIME SYLVER      20.0
# 185      RVG188       VIDRIO GLASS MOTO E6 PLUS NEGRO +OCA +TACTIL       8.0
# 229    RC124158              VIDRIO GLASS SAMSUNG A01 TACTIL +OCA        7.0
# 349      RVG187  VIDRIO GLASS MOTOROLA E6 PLAY NEGRO + OCA +TACTIL       5.0
# 450      RVG185    VIDRIO GLASS MOTO E5 PLAY GO NEGRO +OCA +TACTIL       4.0
# 585        S964                              SERV TEC TACTIL Y LCD       3.0
# 599      RT1001  Touch TPC-51055 V3.0 / FPC-TP070215(708B) / FP...       3.0
# 606      RVG163       VIDRIO GLASS MOTO G5S PLUS NEGRO TACTIL +OCA       3.0
# 631      AU3281       AURICULARES BT NOGA NG-BTWINS 26 TACTIL ROJO       2.0
# 862      RVG192                           TACTIL  LG K40s NEGRO +O       2.0
# 885     R101118  Touch Mas Simple 8 pulgadas / L201190610 06.38...       2.0
# ...

# %%
#agregar la cadena 'Tactil' en la columna categoria si el valor tiene estrictamente la cadena touch como primera cadena de su valor
df.loc[df['Nombre del Producto'].str.contains('^touch', case=False), 'Categoria'] = 'Tactil'

# %%
#ver valores con la cadena touch philco
df[df['Nombre del Producto'].str.contains('touch philco', case=False)]
# Out:
#      Código                  Nombre del Producto  Cantidad  Costo total  \
# 908  RT1066  4B1 Touch Philco TP7A1I / PB70A2229       1.0         2.99
#
#         Ganancia  Ganancia prom. %  Venta total  \
# 908  7996.697614          267459.0       8000.0
#
#                                Categoria
# 908  4B1 Touch Philco TP7A1I / PB70A2229

# %%
#agregar la cadena "Tactil" en la columna categoria si la columna "Nombre del Producto" contiene la cadena touch philco
df.loc[df['Nombre del Producto'].str.contains('touch philco', case=False), 'Categoria'] = 'Tactil'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      103
# Vidrio Glass                                                    96
#                                                               ...
# MASCARA UV RELIFE - Negro                                        1
# Placa de Red PCI-E 300N 2x 2Dbi Tp-Link TL-WN881ND               1
# BASTON SELFI STICK 3 GEN. QUALITY BLUETOOH 78 CM CON CABLE       1
# TRIPODE BRACKET H-08 COLORES                                     1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 112, dtype: int64

# %%
#ver valores con la cadena sim
df[df['Nombre del Producto'].str.contains('sim', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 248    CE8153    CELULAR NOKIA 106 Dual SIM 4 MB RAM GRIS OSCURO       6.0
# 335       C78  Pin Carga Tipo C Tablet Anses Mas Simple / Gad...       5.0
# 454     B2000             ADAPTADOR DE NANO SIM A MICRO SIM 2384       3.0
# 744      2741    Joystick PS3 Bluetooth Sony Dualshock 3 SIMIL O       2.0
# 885   R101118  Touch Mas Simple 8 pulgadas / L201190610 06.38...       2.0
# 962   AU60232  Auricular CON Vincha en metal y simil cuero 20...       1.0
# 979      B130                         BANDEJA SIM S10 / S10 PLUS       1.0
# 980      B100  BANDEJA SIM SAM A10 / A10S / A20 / A30 / A50 /...       1.0
# 981      B131                                BANDEJA SIM SAM A31       1.0
# 982      B116                BANDEJA SIM SAM S8 / S8 PLUS SYLVER       1.0
# 1201     B128                           LECTOR SIM MOTO G7 POWER       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# ...

# %%
#agregar la cadena "Badeja SIM" en la columna categoria si la columna "Nombre del Producto" contiene la cadena lector sim
df.loc[df['Nombre del Producto'].str.contains('sim', case=False), 'Categoria'] = 'Badeja SIM'

# %%
#ver valores que tengan la cadena lector
df[df['Nombre del Producto'].str.contains('lector', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 331   PA131159  PARLANTE PORTATIL RADIO Y LECTOR TARJETA YX-07...       5.0
# 399     AD7076                 Lector De Memoria Micro SD NO:2400       4.0
# 527     AD7099               Lector De Memorias Sd Micro Sd A Usb       3.0
# 752      A7067  Lector De Memoria Usb A Micro Sd Compacto HT-279A       2.0
# 753     TE5775  Lector de Codigo de barras Laser Inalambrico 1...       2.0
# 1201      B128                           LECTOR SIM MOTO G7 POWER       1.0
# 1213   TE10936  Lector de Codigo de barras Laser USB 1D CON SO...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 331         58.40  123929.336000      2.122290e+05     124000.0
# 399          1.44   10698.267877      7.429560e+05      10700.0
# 527          1.71    6997.945205      4.092570e+05       7000.0
# 752          0.06    3499.917123      5.833230e+11       3500.0
# ...

# %%
#ver valores en nombre de producto tengan la cadena lector y no tenga las cadenas: parlante, sim
df[df['Nombre del Producto'].str.contains('lector', case=False) & ~df['Nombre del Producto'].str.contains('parlante|sim', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 399    AD7076                 Lector De Memoria Micro SD NO:2400       4.0
# 527    AD7099               Lector De Memorias Sd Micro Sd A Usb       3.0
# 752     A7067  Lector De Memoria Usb A Micro Sd Compacto HT-279A       2.0
# 753    TE5775  Lector de Codigo de barras Laser Inalambrico 1...       2.0
# 1213  TE10936  Lector de Codigo de barras Laser USB 1D CON SO...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 399          1.44  10698.267877      7.429560e+05      10700.0
# 527          1.71   6997.945205      4.092570e+05       7000.0
# 752          0.06   3499.917123      5.833230e+11       3500.0
# 753         59.02  96434.784817      1.715370e+05     101300.0
# 1213        26.37  42970.861301      1.629640e+05      43000.0
#
#                                               Categoria
# 399                  Lector De Memoria Micro SD NO:2400
# ...

# %%
#agregar la cadena "Lector" en la columna categoria si la columna "Nombre del Producto" contiene la cadena lector y no tiene las cadenas parlante y sim
df.loc[df['Nombre del Producto'].str.contains('lector', case=False) & ~df['Nombre del Producto'].str.contains('parlante|sim', case=False), 'Categoria'] = 'Lector'

# %%
#ver valores unicos en la cadena categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# HD EXTERNO 1TB PORTABLE WD ELEMENTS BLACK USB 3.0 Negro          1
# JUEGO DE AJEDREZ TABLERO MAGNETICO 3881A                         1
# MASCARA UV RELIFE - Negro                                        1
# Placa de Red PCI-E 300N 2x 2Dbi Tp-Link TL-WN881ND               1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 107, dtype: int64

# %%
#ver valores con la cadena serv tec
df[df['Nombre del Producto'].str.contains('serv tec', case=False)]
# Out:
#     Código    Nombre del Producto  Cantidad  Costo total  Ganancia  \
# 584   S961           SERV TEC PIN       3.0          0.0   38000.0
# 585   S964  SERV TEC TACTIL Y LCD       3.0          0.0   49000.0
#
#      Ganancia prom. %  Venta total              Categoria
# 584               NaN      38000.0           SERV TEC PIN
# 585               NaN      49000.0  SERV TEC TACTIL Y LCD

# %%
#agregar la cadena "Servicio Tecnico" en la columna categoria si la columna "Nombre del Producto" contiene la cadena serv tec
df.loc[df['Nombre del Producto'].str.contains('serv tec', case=False), 'Categoria'] = 'Servicio Tecnico'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# JUEGO DE AJEDREZ TABLERO MAGNETICO 3881A                         1
# MASCARA UV RELIFE - Negro                                        1
# Placa de Red PCI-E 300N 2x 2Dbi Tp-Link TL-WN881ND               1
# TRIPODE BRACKET H-08 COLORES                                     1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 105, dtype: int64

# %%
#ver valores con la cadena hdmi
df[df['Nombre del Producto'].str.contains('hdmi', case=False)]
# Out:
#              Código                                Nombre del Producto  \
# 48           AD7052      CONVERSOR HDMI A VGA CON CABLE AUDIO SM-C7819
# 65    SHDMI2.0-1.5M    Cable Hdmi 2.0 Ultra Hd 4K X 1,5M Shdmi2.0-1.5M
# 198        CA796537  CABLE HDMI 3 EN 1 CON ADAPTADORES CAB-6568 / T...
# 249         CA74197  Cable HDMI V1.4 (3Mtrs) soporta 3D Bolsa Netma...
# 250     SHDMI2.0-3M        Cable Hdmi 2.0 Ultra Hd 4K X 3M Shdmi2.0-3M
# 252          AD7051  Conversor Display Port A a HDMI Full HD 1080p ...
# 305          CA7965  Cable HDMI-HDMI 1.5mtrs (V1.4) 3D Bolsa Netmak...
# 378     SHDMI2.0-5M        Cable Hdmi 2.0 Ultra Hd 4K X 5M Shdmi2.0-5M
# 464          06-009   Adaptador Displayport Macho A Hdmi Hembra 06-009
# 486    SHDMI2.0-10M      Cable Hdmi 2.0 Ultra Hd 4K X 10M Shdmi2.0-10M
# 487          CA1-5M                 Cable Hdmi A Hdmi 1.5M Color Negro
# 592          AD2147                 SPLITTER HDMI 1 A 2 4K / ADP-48006
# ...

# %%
#ver valores con que tengan la cadena hdmi y que su categoria sea distinta de: cable, adaptador, conversor, consola, luces
df[df['Nombre del Producto'].str.contains('hdmi', case=False) & ~df['Categoria'].str.contains('cable|adaptador|conversor|consola|luces', case=False)]
# Out:
#        Código                             Nombre del Producto  Cantidad  \
# 592    AD2147              SPLITTER HDMI 1 A 2 4K / ADP-48006       3.0
# 887    AD2146  VGA MACHO A HDMI HEMBRA FULL HD 1080 ADP-48007       2.0
# 1046   AD7077                    CAPTURADORA HDMI A USB HU-03       1.0
# 1162  CA79115  HDMI SPLITTER 1 x 4 DUPLICA 4KX2K 3D SM-C7830K       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 592         23.22  42871.903800          184655.0      42900.0
# 887         12.20  22585.238000          185146.0      22600.0
# 1046         6.91  13491.643265          195269.0      13500.0
# 1162         8.27  14489.994709          175233.0      14500.0
#
#                                            Categoria
# 592               SPLITTER HDMI 1 A 2 4K / ADP-48006
# 887   VGA MACHO A HDMI HEMBRA FULL HD 1080 ADP-48007
# 1046                    CAPTURADORA HDMI A USB HU-03
# 1162  HDMI SPLITTER 1 x 4 DUPLICA 4KX2K 3D SM-C7830K

# %%
#agregar la cadena "Adaptador" en la columna categoria si la columna "Nombre del Producto" contiene la cadena hdmi y su categoria es distinta de cable, adaptador, conversor, consola, luces
df.loc[df['Nombre del Producto'].str.contains('hdmi', case=False) & ~df['Categoria'].str.contains('cable|adaptador|conversor|consola|luces', case=False), 'Categoria'] = 'Adaptador'

# %%
#ver valores que tengna la cadena splitter
df[df['Nombre del Producto'].str.contains('splitter', case=False)]
# Out:
#        Código                             Nombre del Producto  Cantidad  \
# 592    AD2147              SPLITTER HDMI 1 A 2 4K / ADP-48006       3.0
# 1162  CA79115  HDMI SPLITTER 1 x 4 DUPLICA 4KX2K 3D SM-C7830K       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  Categoria
# 592         23.22  42871.903800          184655.0      42900.0  Adaptador
# 1162         8.27  14489.994709          175233.0      14500.0  Adaptador

# %%
#agregar la cadena "Conversor" en la columna categoria si la columna "Nombre del Producto" contiene la cadena splitter
df.loc[df['Nombre del Producto'].str.contains('splitter', case=False), 'Categoria'] = 'Conversor'

# %%
#agregar la cadena "Conversor" en la columna categoria si la columna "Nombre del Producto" contiene la cadena capturadora hdmi
df.loc[df['Nombre del Producto'].str.contains('capturadora hdmi', case=False), 'Categoria'] = 'Conversor'

# %%
#ver valores que tengan estrictamente la cadena "LED"
df[df['Nombre del Producto'].str.contains('LED', case=False)]
# Out:
#        Código                                Nombre del Producto  Cantidad  \
# 53    RC85420  Modulo Pantalla Moto G72 - G52 5G - G82 5G - E...      19.0
# 86    RC85467  Modulo Pantalla Xiaomi Note 10 Pro / Note 11 P...      13.0
# 95    RC85395  Modulo Pantalla Samsung A52 / A52S 5G Oled Con...      12.0
# 96       R538     Modulo Pantalla Samsung J7 Pro J730 Oled Negro      12.0
# 102    LU8038  Aro Luz Led 30CM RGB + Tripode 2.1m HX-MJ30 / ...      11.0
# ...       ...                                                ...       ...
# 1405   PR1500  Proyector mini ViewSonic M1 MINI LED 120LM Ent...       1.0
# 1439  HE18544           SOPORTE CON LUPA Y LUZ LED TE800 EC01039       1.0
# 1468  HE18511  TRINO MICROSCOPIO WIFIX WF-M50XT / 50X ZOOM / ...       1.0
# 1469  HE89313  TRINO MICROSCOPIO kailiwei 10HT-B1 NEGRO + ADA...       1.0
# 1499   GA9012  Turbina Cooler 12 cm con 15 Leds Rgb Netmak NM...       1.0
#
# ...

# %%
#ver valores con la cadena neon
df[df['Nombre del Producto'].str.contains('neon', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 563   LU1991             NEON RGB KIT LED-3535NH72TZ-12V-RGB 5M       3.0
# 1222  LU1968  MANGUERA LUCES NEON LED FLEXIBLE 5MTS COLORES ...       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 563         74.55  133409.79450          178974.0     133500.0
# 1222        13.81   23983.28653          173687.0      24000.0
#
#                                    Categoria
# 563   NEON RGB KIT LED-3535NH72TZ-12V-RGB 5M
# 1222                                   Luces

# %%
#agregar la cadena "Luces" en la columna categoria si la columna "Nombre del Producto" contiene la cadena neon
df.loc[df['Nombre del Producto'].str.contains('neon', case=False), 'Categoria'] = 'Luces'

# %%
#ver valores con la cadena kit
df[df['Nombre del Producto'].str.contains('kit', case=False)]
# Out:
#                Código                                Nombre del Producto  \
# 106            TE5840  KIT COMBO TECLADO Y MOUSE INALMBRICO 2.4G SLIM...
# 167            TE5842          KIT MOUSE Y TECLADO INALAMBRICO EZRA KB03
# 255            TE5844  KIT TECLADO Y MOUSE 2,4G INALAMBRICO ULTRA DEL...
# 313             H1507  KIT DESTORNILLADORES PARA CELULARES YAXUN YX-6029
# 314              H890   Kit Destornilladores Yaxun YX6028 Tablet Celular
# 385            SO5542       ESTABILIZADOR KIT CON LUZ Y MICROFONO AY-49U
# 437           HE18415                 SET X3 SPUDGER METALICOS KIT RL065
# 440   TVS-ARM2-30-60I  SOPORTE TV DOBLE BRAZO MOVIL GLOBAL 30 A 60 IN...
# 518             H9046  KIT DESTORNILLADORES SS-5106 PARA iPHONE 7 (4 ...
# 519           HE18495              KIT PINZAS PARA PEGAR MODULO TG-4000
# 520           HE89342   Kit Destornilladores Yaxun YX6310 Tablet Celular
# 521           TE11120  Kit de Teclado y Mouse inalambrico Logitech MK...
# ...

# %%
#ver valores con la cadena tira de led
df[df['Nombre del Producto'].str.contains('tira de led', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 111   CA712086  TRANSFORMADOR FUENTE TIRA DE LED CCTV CAMARAS ...      11.0
# 1188    LU1998              KIT COMBO TIRA DE LED RGB LED-Y3528RD       1.0
#
#       Costo total      Ganancia  Ganancia prom. %  Venta total  \
# 111         38.83  99953.039848          257433.0  100000.0047
# 1188         8.86  15889.279400          224223.0   19875.0000
#
#                                   Categoria
# 111                             Herramienta
# 1188  KIT COMBO TIRA DE LED RGB LED-Y3528RD

# %%
#agregar la cadena "Luces" en la columna categoria si la columna "Nombre del Producto" contiene la cadena tira de led y no tiene la cadena transformador
df.loc[df['Nombre del Producto'].str.contains('tira de led', case=False) & ~df['Nombre del Producto'].str.contains('transformador', case=False), 'Categoria'] = 'Luces'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# FILM MEMBRANA CONDUCTOR JOYSTICK PS4 JDM-040                     1
# HD EXTERNO 1TB PORTABLE WD ELEMENTS BLACK USB 3.0 Negro          1
# JUEGO DE AJEDREZ TABLERO MAGNETICO 3881A                         1
# MASCARA UV RELIFE - Negro                                        1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 95, dtype: int64

# %%
#ver con la cadeena mini led
df[df['Nombre del Producto'].str.contains('mini led', case=False)]
# Out:
#       Código                                Nombre del Producto  Cantidad  \
# 1234  LU1987  MINI LED DE CABEZA MOVIL MULTICOLORES 7LED 10w...       1.0
# 1405  PR1500  Proyector mini ViewSonic M1 MINI LED 120LM Ent...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  \
# 1234        61.00  115926.190000          190064.0     116000.0
# 1405       125.57  259848.059361          206956.0     260000.0
#
#                                               Categoria
# 1234  MINI LED DE CABEZA MOVIL MULTICOLORES 7LED 10w...
# 1405                                              Luces

# %%
#agregar la cadena "Luces" en la columna categoria si la columna "Nombre del Producto" contiene la cadena mini led
df.loc[df['Nombre del Producto'].str.contains('mini led', case=False), 'Categoria'] = 'Luces'

# %%
#ver valores con la cadena gaming
df[df['Nombre del Producto'].str.contains('gaming COMBO'
                                          , case=False)]
# Out:
#        Código          Nombre del Producto  Cantidad  Costo total  \
# 1158  TE11115  GAMING COMBO 4 EN 1 NKB-405       1.0        14.59
#
#           Ganancia  Ganancia prom. %  Venta total                    Categoria
# 1158  41983.883525          359736.0      52500.0  GAMING COMBO 4 EN 1 NKB-405

# %%
#agregar la cadena "Kit Gaming" en la columna categoria si la columna "Nombre del Producto" contiene la cadena gaming COMBO
df.loc[df['Nombre del Producto'].str.contains('gaming COMBO', case=False), 'Categoria'] = 'Kit Gaming'

# %%
#ver valores con la cadena tripode
df[df['Nombre del Producto'].str.contains('tripode', case=False)]
# Out:
#         Código                                Nombre del Producto  Cantidad  \
# 102     LU8038  Aro Luz Led 30CM RGB + Tripode 2.1m HX-MJ30 / ...      11.0
# 191      L8020  Aro Luz Led 26cm Blanco Frio Calido + Tripode ...       7.0
# 341     SO5539  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,02...       5.0
# 342     SO5540  TRIPODE PARA CELULARES O CAMARAS DE HASTA 1,40...       5.0
# 866       S934                       TRIPODE BRACKET H-08 COLORES       2.0
# 1229      M786  MICROFONO CONDENSER/SEISA  CON TRIPODE SF-666 ...       1.0
# 1261  SO938417  Mini Tripode Universal Altura Regulable Netmak...       1.0
# 1528     C7418  Webcam 720P HD C/Microfono y Tripode Netmak NM...       1.0
#
#       Costo total       Ganancia  Ganancia prom. %  Venta total  Categoria
# 102        168.00  322896.707568          192221.0     323100.0      Luces
# 191         74.69  150709.603828          201801.0     150800.0      Luces
# ...

# %%
#agregar la cadena "Tripode" en la columna categoria si la columna "Nombre del Producto" contiene la cadena tripode y si columna catgoria es distinta de Luces,Microfono
df.loc[df['Nombre del Producto'].str.contains('tripode', case=False) & ~df['Categoria'].str.contains('Luces|Microfono', case=False), 'Categoria'] = 'Tripode'

# %%
#ver valores unicos en la columna categoria
df['Categoria'].value_counts()
# Out:
# Categoria
# Herramienta                                                    213
# Modulo                                                         125
# Bateria                                                        115
# Auricular                                                      102
# Vidrio Glass                                                    96
#                                                               ...
# FILM MEMBRANA CONDUCTOR JOYSTICK PS4 JDM-040                     1
# HD EXTERNO 1TB PORTABLE WD ELEMENTS BLACK USB 3.0 Negro          1
# JUEGO DE AJEDREZ TABLERO MAGNETICO 3881A                         1
# MASCARA UV RELIFE - Negro                                        1
# XMI GAME BOX EMULADOR  10MIL JUEGOS 64GB + ANDROID + TV BOX      1
# Name: count, Length: 95, dtype: int64

# %%
#guardar como excel
df.to_excel('Reporte de ventas por articulos MOD 2.xlsx', index=False)
